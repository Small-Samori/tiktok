# %%
import requests
import dotenv
import os, time
import pandas as pd

dotenv.load_dotenv()
# Out:
# True

# %%
scratch = os.getenv('SCRATCH')
hashtag_folder = f"{scratch}/tiktok/hashtag_data"

oak = os.getenv('OAK')
video_folder = f"{oak}/samori/tiktok/test_folder2"
os.path.exists(video_folder)
# Out:
# False

# %%
def get_access_token(client_key, client_secret):
    
    endpoint_url = "https://open.tiktokapis.com/v2/oauth/token/"
    headers = {
        'Content-Type': 'application/x-www-form-urlencoded',
    }

    data = {
        'client_key': client_key,
        'client_secret': client_secret,
        'grant_type': 'client_credentials'
    }

    response = requests.post(endpoint_url, headers=headers, data=data)

    if response.status_code == 200:
        response_json = response.json()
        return response_json
        
    else:
        # If the request was not successful, print the error response JSON
        print("Error:", response.json())

# %%
def make_request_video(endpoint, query_body, query_params, headers, save_folder):
    start_date = query_body["start_date"]
    end_date = query_body["end_date"]
    prev_cursor = query_body["cursor"]
    
    if prev_cursor > 0:
        prev_search_id = query_body["search_id"]

    # make post request
    response = requests.post(endpoint, json=query_body, params=query_params, headers=headers)

    # checking if request was successful
    if response.status_code != 200:
        i = 0
        # retrying request 10 times if request was unsuccessful
        while i < 10 and response.status_code != 200:
            response = requests.post(endpoint, json=query_body, params=query_params, headers=headers)
            time.sleep(5)
            i += 1
        # increasing cursor to see if there will be some luck
        while response.status_code == 500:
            current_cursor =  query_body['cursor']
            query_body.update({"cursor": current_cursor+10})
            response = requests.post(endpoint, json=query_body, params=query_params, headers=headers)
            time.sleep(5)
            
        if response.status_code != 200:
            status_code = response.status_code
            print("Error code", response.status_code)
            print(response.json())
            return query_body["search_id"], False, query_body["cursor"], str(response.json()), status_code

    status_code = response.status_code
    
    # extracting information for pagination
    data = response.json().get("data", {})
    
    has_more = data["has_more"]
    cursor = data["cursor"]

    print(data)
    if not "search_id" in list(data.keys()) and prev_cursor > 0:
        search_id = prev_search_id
    else:
        search_id = data["search_id"]
        
    # if len(data['videos']) != 0 and : # note: update to be compatible with other endpoints
    #     search_id = data["search_id"]
    # else:
    #     search_id = -1

    # saving queried data
    videos = data.get("videos", []) # note: update to be compatible with other endpoints
    df = pd.DataFrame(videos)
    return df
    # df.to_csv(f"{save_folder}/videos_{start_date}_{end_date}_{cursor}_{search_id}.csv", index=False)

    # return search_id, has_more, cursor, len(df), status_code

# %%
client_key = os.getenv("CLIENT_KEY")
client_secret = os.getenv("CLIENT_SECRET")

credentials = get_access_token(client_key, client_secret)
access_token = credentials["access_token"]
token_type = credentials["token_type"]

endpoints_dict = {"video": "https://open.tiktokapis.com/v2/research/video/query/"}

# %%
fields = "id,video_description,create_time,region_code,share_count,view_count,like_count,comment_count,music_id,hashtag_names,username,effect_ids,playlist_id,voice_to_text,is_stem_verified,favorites_count,video_duration"
fields = "id,video_description"

query = {
    "and": [
        {
            "operation":"EQ",
            "field_name":"keyword",
            "field_values":["f3nt\\@nyl"]
        },
        {
            "operation":"EQ",
            "field_name":"region_code",
            "field_values":["US"]
        }
        
    ]
}

cursor = 0
start_date = "20240401"
end_date = "20240430"
save_folder = "."
endpoint_name = "video"

# %%
query_params = {"fields": fields}
query_body = {"query":query, "max_count":100, "cursor":cursor,
              "start_date":str(start_date), "end_date":str(end_date)}
headers = {"Content-Type": "application/json; charset=utf-8",
           "Accept-Charset": "utf-8",
           "Authorization": f"{token_type} {access_token}"}
# headers = {"Content-Type": "application/json",
#            "Authorization": f"{token_type} {access_token}"}

endpoint = endpoints_dict[endpoint_name]

# %%
df = make_request_video(endpoint, query_body, query_params, headers, save_folder)
if len(df) != 0:
    df = df[["id","video_description"]]
    df.to_csv("test_vid3.csv", index=False)
df
# Out:
# {'cursor': 100, 'has_more': True, 'search_id': '7450706973907178542', 'videos': [{'id': 7363813228310334766, 'video_description': "#thekylabook10xbeatsaber #thegorillabook9xgorilatag #tgb9xgt #tkb10xbs #beatsaber #vr #expertplusbeatsaber #deathb20xkylazizzy✅ #songedit #game #beatsabervrsongs (tagged): @Nicholas 17carter captain 141 @nicole_isthebest6 @Mocha the gacha player<3🫶🏼 @❄️🛡️💙Death B 2.0💙⚔️⚡ @zay @springfoxy the fox @🎸Milo🎸 @ANGEL!!! @olivia_and_oliveira_sisters @Jaimelyndimitrsecu21 @little mask cherry @Joshuaexpro @☆࿐ཽ༵༆༒W༒༆࿐ཽ༵☆ @Meli_hate_tails07173727 @Nyla!! 🩷🐾 @💕Murders drones 💕 @🐝💛 Valentina the weasel 🐝💛 @willow and friends🍬🍥🍭🍰🍡🍫 @☯♐︎Willow X Tigry ✡☯⚧☮ @Willow and Olivia🎆🎇💮💜🩷🩵 @◌⑅⃝●♡⋆♡ ꫀׁׅܻ݊ᨮׁׅ֮᥊ׁׅ^^ ♡⋆♡●⑅⃝◌ @🍭🌸🍰Samantha🦄🎀💖 @☻KittenGalaxy☺︎ @⚡️🔵 ꧁XML The Hedgehog꧂🔵⚡️ 𓇽 @y҉/n҉  exe🤍🏳️\u200d🌈🥀 @[🩵💙] « AKIRA ! » @🕷⌛🦁¿the animal thing? ⌛🦁🕷 @❤️BF (murder drones)🩵 @DanielHernandez @Queen Alastoria_Frenni_editz💖 @Wassup I'm am Ava🎁🎄 @Philip Alindayu "}, {'id': 7363810531293105451, 'video_description': 'Polypropylene doll hair is soft, versatile and super voluminous! It’s a lot like Nylon hair but even more voluminous! Fun fact: Polypropylene is non porous so it can’t be dyed! That’s a surefire way to tell the difference between Polypropylene and Nylon hair. Find them both in a variety of colors on Dollyhair💕 #reroot #dollhair #ooak #customdoll #polypropylene #dollyhair '}, {'id': 7363809253255089451, 'video_description': "#AIZETSU for editing comp! #nezustrawbzeditingcomp @𝓔🎀ྀིྀི #fyppp #demonslayermugentrain #demonslayer #demonslayermugentrain #demonslayeredits #demonslayeredits #fyppppppppppppppppppppppp #fyppppppppppppppppppppppp #demonslayerseason3 #demonslayerseason1 #aizetsukny #hantengu @God is good @⋆˙⟡ ɴɪʟᴀ ⋆˙⟡ @1leftdog_ @‼️Alastor‼️ @kenzie🪼💕 @ɢɪᴀɴɴᴀ @☆ A M A N D A ☆ @. :*☆nyla☆*: . @꧁❦︎ꪶꫀꪖꫝ❦︎꧂ @• ᴀ ɴ ɢ ɪ ᴇ ☁️💤 • @|| BIGJJ⁉️⁉️ || @͙͘͡★ morgan @☆M4RSHALL☆ @♡ Esil // Mui's lover ♡ @🌷 ᴇᴍ // ᴍᴜɪ'ꜱ + ᴍɪᴛꜱᴜ'ꜱ ɴᴜ1 ☁ @🧍\u200d♂️🧌🏂🏋️\u200d♂️ @♡ @AYAYAYAYA ☆～（ゝ。∂） @hypno🔮 (homuras version) @justeymar @Nang Zami @jen "}, {'id': 7363806798698106154, 'video_description': 'Get those Roommate Requests In!🛌 No roommate request - no problem. Great new friends are on the way🤞 1. Go to myenvisionexperience.com \t2.\tLogin\xa0 \t3.\tClick on Enrollment Forms and Info\xa0 4. Go to Preparing for your program tab\xa0 5. Click on roommate application request\xa0 6. You will be directed to Roommate Request System; Make sure your information is correct and click "NEXT" 7. On Find Roommate tab type in the last name of the scholar you would like to room with and "Search"\xa0 8. Scholars with that last name will appear; make sure to Click on the empty box next to the scholar they want to request and hit "NEXT"\xa0 9. On the Confirmation Page make sure the information you entered is correct and hit "I confirm the details of this roommate request" and then click finish #NYLF #Roommate #FYP #WorldStrides #EnvisionExperience #LinkInBio #CareerExploration  '}, {'id': 7363804537871699243, 'video_description': 'Enjoy the ambience. Pretty much my favorite song. “She Always Takes It Black” by Gregory Alan Isakov. #cover #fyp #folkmusic #gregoryalanisakov #weatherman #fingerpicking #nylonstring #softmusic #lovesong '}, {'video_description': 'Are changes inevitable in Toronto? #nhl #hockey #playoffs #stanleycup #stanleycupplayoffs #espn #pti #pardontheinterruption #toronto #mapleleafs #leafs #matthews #marner #nylander #boston #bruins ', 'id': 7363800634253905198}, {'id': 7363799270626970922, 'video_description': 'like?? 🤨🤨 @t.astou 🍉 @kellen @nyla b 🌟 #nylastou #blowthisup #viral #twintowers #wbb'}, {'id': 7363797842143513902, 'video_description': 'all they did was post rage bait and be hypocritical they were annoying #emusl1t #atsushi #gojo #autistic #fypage #fyp #fyppppppppppppppppppppppp #fypシ #fypシ゚viral #foryou #foryoupage #fy #relatable #xybca #hatsunemikucolorfulstage #projectsekai #pjsk #prosekai #ruikamishiro @nyla🌶🍜 @Nami 🍗🍜 @Sungdripw ...
#                      id                                  video_description
# 0   7363813228310334766  #thekylabook10xbeatsaber #thegorillabook9xgori...
# 1   7363810531293105451  Polypropylene doll hair is soft, versatile and...
# 2   7363809253255089451  #AIZETSU for editing comp! #nezustrawbzediting...
# 3   7363806798698106154  Get those Roommate Requests In!🛌 No roommate r...
# 4   7363804537871699243  Enjoy the ambience. Pretty much my favorite so...
# 5   7363800634253905198  Are changes inevitable in Toronto? #nhl #hocke...
# 6   7363799270626970922  like?? 🤨🤨 @t.astou 🍉 @kellen @nyla b 🌟 #nylast...
# 7   7363797842143513902  all they did was post rage bait and be hypocri...
# 8   7363794789466148127                    #CapCut  @Nylah Louise Tunstil
# 9   7363794649040899371  The Frying Pan for a sunset meal at Hudson Riv...
# 10  7363792735712628010  #eatingraisingcanes #birthdaydinner @D-Nyle #f...
# 11  7363790658823327022  Nylah sat there and ate all of them smh 🤦‍♀️ @...
# 12  7363790376420920622  #customizednylon #printersoftiktok  #trending ...
# 13  7363789699380546859  3 Bed 2 Bath Apartment in Pelham Bay, Bronx! #...
# 14  7363786476578147627  My biggest motivator is being able to say ever...
# 15  7363786087128419626  Men design braids🔥   #boxbraids #zigzag #menbr...
# 16  7363783316266306862  Imagine elven lands.  #filmscore #oddtimesigna...
# 17  7363781969588702510  5 Facts- Moring Ropes For Cruise Ships 1. **Ma...
# 18  7363781215788272939  #lalaland mia & sebastian’s theme . (learned b...
# 19  7363779979336748331  Ngl yall im bored asf #katsukibakugou #bakugou...
# 20  7363774318142131502  Check out my Saturday video 😍😛 ||tags;;  #d3me...
# 21  7363772150504770859                                       @k4sh.nylah
# 22  7363768772567584043  6 of 9 Finishing "Now You Don't" invisible bob...
# 23  7363768515754609963  These were so fun to open😭😭 MINISO, WE NOT GON...
# 24  7363768291476737322  My Sunday breakfast look, the exciting return ...
# 25  7363767772238630186  #lgbtq🌈🌈tiktok #420lesbian #butchoftiktok🌈 #le...
# 26  7363763531990175019  if you cant tell i cry over the small things #...
# 27  7363761310665805087  Looking for a touch of elegance? Try our wispy...
# 28  7363757520994929966  #coils #curls #coilyhair #curlyhair #natural #...
# 29  7363757055510859050  necesitas un carrito Llama a Miguelito. The Ny...
# 30  7363756014576946478  🎉WE DID IT! Rain didn’t stop our shine at The ...
# 31  7363754925823741227  What meeting Aaron and Tailored Health entails...
# 32  7363750930438802731  romance books that are a touch (or more) of ta...
# 33  7363747198032432426  Dont have many colored pantyhose but think i m...
# 34  7363741154082360619  [#SANEMI]~|| I dont know if i really like how ...
# 35  7363739950065454367  Ruger LCP 380 in bubblegum pink kydex with ult...
# 36  7363738872364158251  Drake me personally… #fyp #foryou #nylanb #ken...
# 37  7363738492628782379  Need to pack light this summer? Our Stowaway C...

# %%
from urllib.parse import quote
encoded_term = quote("f3nt@nyl")
encoded_term
# Out:
# 'f3nt%40nyl'

# %%
df.to_csv("test_vid.csv", index=False)

# %%
# def query_api(endpoint_name=endpoint_name, fields=fields, 
#               query=query, cursor=cursor, start_date=start_date, 
#               end_date=end_date, save_folder=video_folder):
    
def query_api_video(endpoint_name, fields, query, cursor, 
              start_date,end_date, save_folder):
    
    # getting credentials
    client_key = os.getenv("CLIENT_KEY")
    client_secret = os.getenv("CLIENT_SECRET")
    
    credentials = get_access_token(client_key, client_secret)
    access_token = credentials["access_token"]
    token_type = credentials["token_type"]

    # note: update this to have url of other endpoints
    endpoints_dict = {"video": "https://open.tiktokapis.com/v2/research/video/query/"}
    
    query_params = {"fields": fields}
    query_body = {"query":query, "max_count":100, "cursor":cursor,
                  "start_date":str(start_date), "end_date":str(end_date)}
    headers = {"Content-Type": "application/json",
               "Authorization": f"{token_type} {access_token}"}
    
    endpoint = endpoints_dict[endpoint_name]
    has_more = True

    # pagination loop
    while has_more:
        if cursor != 0:
            query_body.update({"search_id": search_id, 
                               "cursor": cursor})
        search_id, has_more, cursor, samples, status_code = make_request_video(endpoint, query_body, query_params, headers, save_folder)

        with open(f"./download_logs_{start_date}_{end_date}_{search_id}", "a") as f:
            f.write(f"{cursor}\t{has_more}\t{samples}\t{search_id}\t{status_code}\n")

        print(f"{cursor}\t{has_more}\t{samples}\t{search_id}\t{status_code}")
        time.sleep(5)
        
    return status_code

# %%
formal_terms = ["fentanyl", "opioids", "opiates", "morphine", "codeine", "oxycodone", "oxymorphone", "mscontin", "percocet"]
informal_terms = ["sublimaze", "duragesic", "fentanil", "sufentanil", "fentanylum", "fentora", "thebaine", "codiene", "roxanol", 
                     "kadian", "oxycontin", "roxicodone", "roxicet", "endocet", "endocodone", "oxyir", "oxynorm", "hydrocodone", 
                     "vicodinsublimaze", "duragesic", "fentanil", "sufentanil", "fentanylum", "fentora", "thebaine", "codiene", 
                     "roxanol", "kadian", "oxycontin", "roxicodone", "roxicet", "endocet", "endocodone", "oxyir", "oxynorm", 
                     "hydrocodone", "vicodin"]

algospeak_terms = ["paink!ller", "f3nt@nol", "cod3in3", "c0d0n3", "f3nt4nol", "p@1nk!ller", "oxy80s", "0xy80", "m0rph!n3", "m3rph0n3", 
                   "m0rf3n", "c0d3in", "0xyc", "s!zzurp", "0pana", "0xym0rph0ne", "num0rph@n", "m0rf33n"]

# %%
video_folder = f"{oak}/samori/tiktok/test_folder2"
endpoint_name = 'video'
fields = "id,video_description,create_time,region_code,share_count,view_count,like_count,comment_count,music_id,hashtag_names,username,effect_ids,playlist_id,voice_to_text,is_stem_verified,favorites_count,video_duration"
all_opioid_keywords = formal_terms + informal_terms + algospeak_terms
normal_keywords = formal_terms + informal_terms

cursor = 0
# start_date = "20240401"
# end_date = "20240430"


query = {
    "and": [
        {
            "operation":"IN",
            "field_name":"keyword",
            "field_values":normal_keywords
        },
        {
            "operation":"EQ",
            "field_name":"region_code",
            "field_values":["US"]
        }
        
    ]
}

# %%
def get_str_date(month, start_day, end_day):
    month_str = '0'+str(month) if month<10 else str(month)
    start_day_str = '0'+str(start_day) if start_day<10 else str(start_day)
    end_day_str = '0'+str(end_day) if end_day<10 else str(end_day)

    return month_str, start_day_str, end_day_str

# %%
end_day_dict = {
    1:31, 2:28, 3:31, 4:30, 5:31, 6:30, 7:31, 8:31, 9:30, 10:31, 11:30, 12:31
}
months = list(range(1,13))

# %%
start_end_pairs = {month:[(1,15),(15,end_day_dict[month])] for month in months}
start_end_pairs
# Out:
# {1: [(1, 15), (15, 31)],
#  2: [(1, 15), (15, 28)],
#  3: [(1, 15), (15, 31)],
#  4: [(1, 15), (15, 30)],
#  5: [(1, 15), (15, 31)],
#  6: [(1, 15), (15, 30)],
#  7: [(1, 15), (15, 31)],
#  8: [(1, 15), (15, 31)],
#  9: [(1, 15), (15, 30)],
#  10: [(1, 15), (15, 31)],
#  11: [(1, 15), (15, 30)],
#  12: [(1, 15), (15, 31)]}

# %%
status_code = 200
year=2022

for month in months:
    for start, end in start_end_pairs[month]:
        if status_code != 429:
            month_str, start_day_str, end_day_str = get_str_date(month, start, end)
            
            start_date = f"{year}{month_str}{start_day_str}"
            end_date = f"{year}{month_str}{end_day_str}"
            
            print(f"---- {start_date} to {end_date}----")
            
            status_code = query_api_video(endpoint_name=endpoint_name, fields=fields, 
                  query=query, cursor=cursor, start_date=start_date, 
                  end_date=end_date, save_folder=video_folder)
        print('\n')
# Out:
# ---- 20220101 to 20220115----
# Error code 400
# {'error': {'code': 'invalid_params', 'message': 'Should search from index 0 when no search id is provided', 'log_id': '2024090302433311DC9BEC0D0828AB3CEC'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 14
#      10     end_date = f"{year}{month_str}{end_day_str}"
#      12     print(f"---- {start_date} to {end_date}----")
# ---> 14     status_code = query_api_video(endpoint_name=endpoint_name, fields=fields,
#      15           query=query, cursor=cursor, start_date=start_date,
#      16           end_date=end_date, save_folder=video_folder)
#      17 print('\n')
#
# Cell In[5], line 33, in query_api_video(endpoint_name, fields, query, cursor, start_date, end_date, save_folder)
#      30 if cursor != 0:
#      31     query_body.update({"search_id": search_id,
#      32                        "cursor": cursor})
# ---> 33 search_id, has_more, cursor, samples, status_code = make_request_video(endpoint, query_body, query_params, headers, save_folder)
#      35 with open(f"./download_logs_{start_date}_{end_date}_{search_id}", "a") as f:
#      36     f.write(f"{cursor}\t{has_more}\t{samples}\t{search_id}\t{status_code}\n")
#
# Cell In[4], line 31, in make_request_video(endpoint, query_body, query_params, headers, save_folder)
#      29         print("Error code", response.status_code)
#      30         print(response.json())
# ---> 31         return query_body["search_id"], False, query_body["cursor"], str(response.json()), status_code
#      33 status_code = response.status_code
#      35 # extracting information for pagination
#
# KeyError: 'search_id'

# %%
status_code = 200
year=2022

for month in months:
    for start, end in start_end_pairs[month]:
        if status_code != 429:
            month_str, start_day_str, end_day_str = get_str_date(month, start, end)
            
            start_date = f"{year}{month_str}{start_day_str}"
            end_date = f"{year}{month_str}{end_day_str}"
            
            print(f"---- {start_date} to {end_date}----")
            
            status_code = query_api_video(endpoint_name=endpoint_name, fields=fields, 
                  query=query, cursor=cursor, start_date=start_date, 
                  end_date=end_date, save_folder=video_folder)
        print('\n')
# Out:
# ---- 20231101 to 20231115----
# 100	True	64	7410230044255654958	200
# 200	True	54	7410230044255654958	200
# 300	True	67	7410230044255654958	200
# 400	True	59	7410230044255654958	200
# 500	True	66	7410230044255654958	200
# 600	True	72	7410230044255654958	200
# 700	True	75	7410230044255654958	200
# 800	True	72	7410230044255654958	200
# 900	True	62	7410230044255654958	200
# 1000	True	68	7410230044255654958	200
# 1100	True	59	7410230044255654958	200
# 1200	True	59	7410230044255654958	200
# 1300	True	67	7410230044255654958	200
# 1400	True	70	7410230044255654958	200
# 1500	True	60	7410230044255654958	200
# 1600	True	74	7410230044255654958	200
# 1700	True	80	7410230044255654958	200
# 1800	True	70	7410230044255654958	200
# 1900	True	70	7410230044255654958	200
# 2000	True	61	7410230044255654958	200
# 2100	True	58	7410230044255654958	200
# 2200	True	69	7410230044255654958	200
# 2300	True	53	7410230044255654958	200
# 2400	True	53	7410230044255654958	200
# 2500	True	64	7410230044255654958	200
# 2600	True	65	7410230044255654958	200
# 2700	True	66	7410230044255654958	200
# 2800	True	77	7410230044255654958	200
# 2900	True	70	7410230044255654958	200
# 3000	True	75	7410230044255654958	200
# 3100	True	61	7410230044255654958	200
# 3160	False	40	7410230044255654958	200
#
#
# ---- 20231115 to 20231130----
# 100	True	69	7410231524714484779	200
# 200	True	60	7410231524714484779	200
# 300	True	67	7410231524714484779	200
# 400	True	77	7410231524714484779	200
# 500	True	52	7410231524714484779	200
# 600	True	58	7410231524714484779	200
# 700	True	44	7410231524714484779	200
# 800	True	47	7410231524714484779	200
# 900	True	53	7410231524714484779	200
# 1000	True	53	7410231524714484779	200
# 1100	True	51	7410231524714484779	200
# 1200	True	47	7410231524714484779	200
# 1300	True	47	7410231524714484779	200
# 1400	True	56	7410231524714484779	200
# 1500	True	53	7410231524714484779	200
# 1600	True	51	7410231524714484779	200
# 1700	True	46	7410231524714484779	200
# 1800	True	55	7410231524714484779	200
# 1900	True	63	7410231524714484779	200
# 2000	True	66	7410231524714484779	200
# 2100	True	54	7410231524714484779	200
# 2200	True	55	7410231524714484779	200
# 2300	True	64	7410231524714484779	200
# 2400	True	45	7410231524714484779	200
# 2500	True	45	7410231524714484779	200
# 2600	True	51	7410231524714484779	200
# 2700	True	53	7410231524714484779	200
# 2800	True	47	7410231524714484779	200
# 2900	True	70	7410231524714484779	200
# 3000	True	67	7410231524714484779	200
# 3100	True	65	7410231524714484779	200
# 3200	True	55	7410231524714484779	200
# 3229	False	22	7410231524714484779	200
#
#
# ---- 20231201 to 20231215----
# 100	True	69	7410231524714566699	200
# 200	True	59	7410231524714566699	200
# 300	True	42	7410231524714566699	200
# 400	True	62	7410231524714566699	200
# 500	True	53	7410231524714566699	200
# 600	True	44	7410231524714566699	200
# 700	True	56	7410231524714566699	200
# 800	True	58	7410231524714566699	200
# 900	True	56	7410231524714566699	200
# 1000	True	39	7410231524714566699	200
# 1100	True	63	7410231524714566699	200
# 1200	True	59	7410231524714566699	200
# 1300	True	48	7410231524714566699	200
# 1400	True	49	7410231524714566699	200
# 1500	True	60	7410231524714566699	200
# 1600	True	66	7410231524714566699	200
# 1700	True	63	7410231524714566699	200
# 1800	True	53	7410231524714566699	200
# 1900	True	69	7410231524714566699	200
# 2000	True	65	7410231524714566699	200
# 2100	True	58	7410231524714566699	200
# 2200	True	63	7410231524714566699	200
# 2300	True	64	7410231524714566699	200
# 2400	True	58	7410231524714566699	200
# 2500	True	55	7410231524714566699	200
# 2600	True	57	7410231524714566699	200
# 2700	True	57	7410231524714566699	200
# 2800	True	59	7410231524714566699	200
# 2900	True	59	7410231524714566699	200
# 2975	False	39	7410231524714566699	200
#
#
# ---- 20231215 to 20231231----
# Error code 400
# {'error': {'code': 'invalid_params', 'message': 'Should search from index 0 when no search id is provided', 'log_id': '20240903022306930772709589E497C536'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 16
#      12     end_date = f"{year}{month_str}{end_day_str}"
#      14     print(f"---- {start_date} to {end_date}----")
# ---> 16     status_code = query_api_video(endpoint_name=endpoint_name, fields=fields,
#      17           query=query, cursor=cursor, start_date=start_date,
#      18           end_date=end_date, save_folder=video_folder)
#      19 print('\n')
#
# Cell In[26], line 33, in query_api_video(endpoint_name, fields, query, cursor, start_date, end_date, save_folder)
#      30 if cursor != 0:
#      31     query_body.update({"search_id": search_id,
#      32                        "cursor": cursor})
# ---> 33 search_id, has_more, cursor, samples, status_code = make_request_video(endpoint, query_body, query_params, headers, save_folder)
#      35 with open(f"./download_logs_{start_date}_{end_date}_{search_id}", "a") as f:
#      36     f.write(f"{cursor}\t{has_more}\t{samples}\t{search_id}\t{status_code}\n")
#
# Cell In[25], line 31, in make_request_video(endpoint, query_body, query_params, headers, save_folder)
#      29         print("Error code", response.status_code)
#      30         print(response.json())
# ---> 31         return query_body["search_id"], False, query_body["cursor"], str(response.json()), status_code
#      33 status_code = response.status_code
#      35 # extracting information for pagination
#
# KeyError: 'search_id'

# %%
status_code = 200
year=2023

months = list(end_day_dict.keys())

for month in months:
    for start, end in start_end_pairs[month]:
        if status_code != 429:
            month_str, start_day_str, end_day_str = get_str_date(month, start, end)
            
            start_date = f"{year}{month_str}{start_day_str}"
            end_date = f"{year}{month_str}{end_day_str}"
            
            print(f"---- {start_date} to {end_date}----")
            
            status_code = query_api_video(endpoint_name=endpoint_name, fields=fields, 
                  query=query, cursor=cursor, start_date=start_date, 
                  end_date=end_date, save_folder=video_folder)
        print('\n')
# Out:
# ---- 20230101 to 20230115----
# 100	True	72	7410204094582985771	200
# 200	True	65	7410204094582985771	200
# 300	True	73	7410204094582985771	200
# 400	True	73	7410204094582985771	200
# 500	True	70	7410204094582985771	200
# 600	True	82	7410204094582985771	200
# 700	True	69	7410204094582985771	200
# 800	True	72	7410204094582985771	200
# 900	True	74	7410204094582985771	200
# 1000	True	72	7410204094582985771	200
# 1100	True	63	7410204094582985771	200
# 1200	True	76	7410204094582985771	200
# 1300	True	73	7410204094582985771	200
# 1400	True	71	7410204094582985771	200
# 1500	True	72	7410204094582985771	200
# 1600	True	67	7410204094582985771	200
# 1648	False	41	7410204094582985771	200
#
#
# ---- 20230115 to 20230131----
# 100	True	65	7410204094583018539	200
# 200	True	65	7410204094583018539	200
# 300	True	75	7410204094583018539	200
# 400	True	72	7410204094583018539	200
# 500	True	74	7410204094583018539	200
# 600	True	68	7410204094583018539	200
# 700	True	58	7410204094583018539	200
# 800	True	74	7410204094583018539	200
# 900	True	56	7410204094583018539	200
# 1000	True	76	7410204094583018539	200
# 1100	True	65	7410204094583018539	200
# 1200	True	67	7410204094583018539	200
# 1300	True	69	7410204094583018539	200
# 1400	True	72	7410204094583018539	200
# 1500	True	71	7410204094583018539	200
# 1600	True	68	7410204094583018539	200
# 1700	True	75	7410204094583018539	200
# 1800	True	75	7410204094583018539	200
# 1900	True	70	7410204094583018539	200
# 2000	True	77	7410204094583018539	200
# 2100	True	73	7410204094583018539	200
# 2200	True	68	7410204094583018539	200
# 2300	True	72	7410204094583018539	200
# 2311	False	9	7410204094583018539	200
#
#
# ---- 20230201 to 20230215----
# 100	True	79	7410204094583051307	200
# 200	True	72	7410204094583051307	200
# 300	True	79	7410204094583051307	200
# 400	True	67	7410204094583051307	200
# 500	True	69	7410204094583051307	200
# 600	True	66	7410204094583051307	200
# 700	True	72	7410204094583051307	200
# 800	True	78	7410204094583051307	200
# 900	True	72	7410204094583051307	200
# 1000	True	70	7410204094583051307	200
# 1100	True	56	7410204094583051307	200
# 1200	True	75	7410204094583051307	200
# 1300	True	75	7410204094583051307	200
# 1400	True	62	7410204094583051307	200
# 1500	True	68	7410204094583051307	200
# 1600	True	74	7410204094583051307	200
# 1700	True	61	7410204094583051307	200
# 1800	True	73	7410204094583051307	200
# 1900	True	48	7410204094583051307	200
# 2000	True	67	7410204094583051307	200
# 2100	True	67	7410204094583051307	200
# 2200	True	65	7410204094583051307	200
# 2300	True	74	7410204094583051307	200
# 2400	True	67	7410204094583051307	200
# 2440	False	28	7410204094583051307	200
#
#
# ---- 20230215 to 20230228----
# 100	True	64	7410204169421722666	200
# 200	True	68	7410204169421722666	200
# 300	True	59	7410204169421722666	200
# 400	True	71	7410204169421722666	200
# 500	True	74	7410204169421722666	200
# 600	True	74	7410204169421722666	200
# 700	True	76	7410204169421722666	200
# 800	True	70	7410204169421722666	200
# 900	True	69	7410204169421722666	200
# 1000	True	70	7410204169421722666	200
# 1100	True	82	7410204169421722666	200
# 1200	True	64	7410204169421722666	200
# 1300	True	65	7410204169421722666	200
# 1400	True	67	7410204169421722666	200
# 1500	True	73	7410204169421722666	200
# 1600	True	75	7410204169421722666	200
# 1700	True	71	7410204169421722666	200
# 1800	True	77	7410204169421722666	200
# 1900	True	71	7410204169421722666	200
# 2000	True	73	7410204169421722666	200
# 2100	True	83	7410204169421722666	200
# 2101	False	1	7410204169421722666	200
#
#
# ---- 20230301 to 20230315----
# 100	True	68	7410204169422001194	200
# 200	True	71	7410204169422001194	200
# 300	True	0	7410204169422001194	200
# 400	True	75	7410204169422001194	200
# 500	True	75	7410204169422001194	200
# 600	True	77	7410204169422001194	200
# 700	True	74	7410204169422001194	200
# 800	True	71	7410204169422001194	200
# 900	True	73	7410204169422001194	200
# 1000	True	74	7410204169422001194	200
# 1100	True	79	7410204169422001194	200
# 1200	True	75	7410204169422001194	200
# 1300	True	73	7410204169422001194	200
# 1400	True	78	7410204169422001194	200
# 1500	True	79	7410204169422001194	200
# 1600	True	82	7410204169422001194	200
# 1700	True	77	7410204169422001194	200
# 1800	True	75	7410204169422001194	200
# 1900	True	68	7410204169422001194	200
# 2000	True	67	7410204169422001194	200
# 2100	True	80	7410204169422001194	200
# 2200	True	75	7410204169422001194	200
# 2300	True	63	7410204169422001194	200
# 2400	True	69	7410204169422001194	200
# 2500	True	60	7410204169422001194	200
# 2600	True	77	7410204169422001194	200
# 2684	False	54	7410204169422001194	200
#
#
# ---- 20230315 to 20230331----
# 100	True	74	7410207136262673454	200
# 200	True	86	7410207136262673454	200
# 300	True	80	7410207136262673454	200
# 400	True	83	7410207136262673454	200
# 500	True	66	7410207136262673454	200
# 600	True	73	7410207136262673454	200
# 700	True	67	7410207136262673454	200
# 800	True	67	7410207136262673454	200
# 900	True	80	7410207136262673454	200
# 1000	True	80	7410207136262673454	200
# 1100	True	82	7410207136262673454	200
# 1200	True	82	7410207136262673454	200
# 1300	True	82	7410207136262673454	200
# 1400	True	73	7410207136262673454	200
# 1500	True	77	7410207136262673454	200
# 1600	True	75	7410207136262673454	200
# 1700	True	79	7410207136262673454	200
# 1800	True	64	7410207136262673454	200
# 1900	True	79	7410207136262673454	200
# 2000	True	73	7410207136262673454	200
# 2100	True	77	7410207136262673454	200
# 2200	True	73	7410207136262673454	200
# 2300	True	70	7410207136262673454	200
# 2400	True	79	7410207136262673454	200
# 2500	True	60	7410207136262673454	200
# 2600	True	60	7410207136262673454	200
# 2700	True	70	7410207136262673454	200
# 2793	False	66	7410207136262673454	200
#
#
# ---- 20230401 to 20230415----
# 100	True	74	7410207136262870062	200
# 200	True	81	7410207136262870062	200
# 300	True	76	7410207136262870062	200
# 400	True	76	7410207136262870062	200
# 500	True	78	7410207136262870062	200
# 600	True	72	7410207136262870062	200
# 700	True	80	7410207136262870062	200
# 800	True	75	7410207136262870062	200
# 900	True	76	7410207136262870062	200
# 1000	True	73	7410207136262870062	200
# 1100	True	76	7410207136262870062	200
# 1200	True	74	7410207136262870062	200
# 1300	True	70	7410207136262870062	200
# 1450	True	73	7410207136262870062	200
# 1570	True	70	7410207136262870062	200
# Error code 400
# {'error': {'code': 'invalid_params', 'message': 'Invalid count or cursor', 'log_id': '2024090300492300AFCB7FDE1DD295403F'}}
# 1570	False	{'error': {'code': 'invalid_params', 'message': 'Invalid count or cursor', 'log_id': '2024090300492300AFCB7FDE1DD295403F'}}	7410207136262870062	400
#
#
# ---- 20230415 to 20230430----
# 100	True	66	7410207136263230510	200
# 200	True	76	7410207136263230510	200
# 300	True	85	7410207136263230510	200
# 400	True	81	7410207136263230510	200
# 500	True	70	7410207136263230510	200
# 600	True	79	7410207136263230510	200
# 700	True	62	7410207136263230510	200
# 800	True	62	7410207136263230510	200
# 900	True	76	7410207136263230510	200
# 1000	True	77	7410207136263230510	200
# 1100	True	82	7410207136263230510	200
# 1200	True	76	7410207136263230510	200
# 1300	True	77	7410207136263230510	200
# 1400	True	77	7410207136263230510	200
# 1500	True	78	7410207136263230510	200
# 1600	True	72	7410207136263230510	200
# 1700	True	79	7410207136263230510	200
# 1800	True	74	7410207136263230510	200
# 1869	False	49	7410207136263230510	200
#
#
# ---- 20230501 to 20230515----
# 100	True	77	7410209435265569835	200
# 200	True	77	7410209435265569835	200
# 300	True	66	7410209435265569835	200
# 400	True	72	7410209435265569835	200
# 500	True	76	7410209435265569835	200
# 600	True	76	7410209435265569835	200
# 700	True	76	7410209435265569835	200
# 800	True	78	7410209435265569835	200
# 900	True	74	7410209435265569835	200
# 1000	True	81	7410209435265569835	200
# 1100	True	87	7410209435265569835	200
# 1200	True	85	7410209435265569835	200
# 1300	True	80	7410209435265569835	200
# 1400	True	72	7410209435265569835	200
# 1500	True	74	7410209435265569835	200
# 1600	True	82	7410209435265569835	200
# 1700	True	71	7410209435265569835	200
# 1800	True	71	7410209435265569835	200
# 1900	True	72	7410209435265569835	200
# 2000	True	69	7410209435265569835	200
# 2100	True	69	7410209435265569835	200
# 2200	True	84	7410209435265569835	200
# 2300	True	77	7410209435265569835	200
# 2318	False	13	7410209435265569835	200
#
#
# ---- 20230515 to 20230531----
# 100	True	72	7410209435265635371	200
# 200	True	70	7410209435265635371	200
# 300	True	75	7410209435265635371	200
# 400	True	69	7410209435265635371	200
# 500	True	74	7410209435265635371	200
# 600	True	78	7410209435265635371	200
# 700	True	78	7410209435265635371	200
# 800	True	72	7410209435265635371	200
# 900	True	73	7410209435265635371	200
# 1000	True	75	7410209435265635371	200
# 1100	True	73	7410209435265635371	200
# 1200	True	73	7410209435265635371	200
# 1300	True	75	7410209435265635371	200
# 1400	True	55	7410209435265635371	200
# 1500	True	78	7410209435265635371	200
# 1600	True	79	7410209435265635371	200
# 1700	True	68	7410209435265635371	200
# 1800	True	78	7410209435265635371	200
# 1900	True	63	7410209435265635371	200
# 2000	True	76	7410209435265635371	200
# 2100	True	76	7410209435265635371	200
# 2200	True	75	7410209435265635371	200
# 2300	True	77	7410209435265635371	200
# 2379	False	59	7410209435265635371	200
#
#
# ---- 20230601 to 20230615----
# 100	True	68	7410209435265651755	200
# 200	True	66	7410209435265651755	200
# 300	True	74	7410209435265651755	200
# 400	True	73	7410209435265651755	200
# 500	True	74	7410209435265651755	200
# 600	True	77	7410209435265651755	200
# 700	True	66	7410209435265651755	200
# 800	True	74	7410209435265651755	200
# 900	True	67	7410209435265651755	200
# 1000	True	76	7410209435265651755	200
# 1100	True	73	7410209435265651755	200
# 1200	True	76	7410209435265651755	200
# 1300	True	71	7410209435265651755	200
# 1400	True	65	7410209435265651755	200
# 1500	True	63	7410209435265651755	200
# 1600	True	68	7410209435265651755	200
# 1700	True	69	7410209435265651755	200
# 1800	True	64	7410209435265651755	200
# 1940	True	68	7410209435265651755	200
# 2040	True	71	7410209435265651755	200
# 2140	True	74	7410209435265651755	200
# 2148	False	6	7410209435265651755	200
#
#
# ---- 20230615 to 20230630----
# 100	True	68	7410209435265700907	200
# 200	True	61	7410209435265700907	200
# 300	True	73	7410209435265700907	200
# 400	True	76	7410209435265700907	200
# 500	True	69	7410209435265700907	200
# 600	True	70	7410209435265700907	200
# 700	True	57	7410209435265700907	200
# 800	True	61	7410209435265700907	200
# 900	True	63	7410209435265700907	200
# 1000	True	70	7410209435265700907	200
# 1100	True	58	7410209435265700907	200
# 1200	True	72	7410209435265700907	200
# 1300	True	67	7410209435265700907	200
# 1400	True	71	7410209435265700907	200
# 1500	True	64	7410209435265700907	200
# 1600	True	67	7410209435265700907	200
# 1700	True	67	7410209435265700907	200
# 1800	True	69	7410209435265700907	200
# 1900	True	74	7410209435265700907	200
# 2000	True	69	7410209435265700907	200
# 2100	True	63	7410209435265700907	200
# 2200	True	68	7410209435265700907	200
# 2300	True	74	7410209435265700907	200
# 2354	False	37	7410209435265700907	200
#
#
# ---- 20230701 to 20230715----
# 100	True	65	7410209435265766443	200
# 200	True	60	7410209435265766443	200
# 300	True	67	7410209435265766443	200
# 400	True	66	7410209435265766443	200
# 500	True	80	7410209435265766443	200
# 600	True	71	7410209435265766443	200
# 700	True	74	7410209435265766443	200
# 800	True	75	7410209435265766443	200
# 900	True	64	7410209435265766443	200
# 1000	True	70	7410209435265766443	200
# 1100	True	76	7410209435265766443	200
# 1200	True	65	7410209435265766443	200
# 1300	True	72	7410209435265766443	200
# 1400	True	72	7410209435265766443	200
# 1500	True	71	7410209435265766443	200
# 1600	True	72	7410209435265766443	200
# 1700	True	63	7410209435265766443	200
# 1800	True	74	7410209435265766443	200
# 1900	True	70	7410209435265766443	200
# 2000	True	73	7410209435265766443	200
# 2100	True	72	7410209435265766443	200
# 2200	True	71	7410209435265766443	200
# 2281	False	57	7410209435265766443	200
#
#
# ---- 20230715 to 20230731----
# 100	True	67	7410209435265831979	200
# 200	True	64	7410209435265831979	200
# 300	True	57	7410209435265831979	200
# 400	True	74	7410209435265831979	200
# 500	True	72	7410209435265831979	200
# 600	True	68	7410209435265831979	200
# 700	True	62	7410209435265831979	200
# 800	True	64	7410209435265831979	200
# 900	True	67	7410209435265831979	200
# 1000	True	71	7410209435265831979	200
# 1100	True	75	7410209435265831979	200
# 1200	True	70	7410209435265831979	200
# 1300	True	67	7410209435265831979	200
# 1400	True	68	7410209435265831979	200
# 1500	True	59	7410209435265831979	200
# 1600	True	66	7410209435265831979	200
# 1700	True	62	7410209435265831979	200
# 1800	True	62	7410209435265831979	200
# 1900	True	63	7410209435265831979	200
# 2000	True	65	7410209435265831979	200
# 2100	True	69	7410209435265831979	200
# 2200	True	64	7410209435265831979	200
# 2300	True	64	7410209435265831979	200
# 2400	True	65	7410209435265831979	200
# 2500	True	75	7410209435265831979	200
# 2600	True	64	7410209435265831979	200
# 2700	True	58	7410209435265831979	200
# 2800	True	66	7410209435265831979	200
# 2865	False	38	7410209435265831979	200
#
#
# ---- 20230801 to 20230815----
# Error code 400
# {'error': {'code': 'invalid_params', 'message': 'Should search from index 0 when no search id is provided', 'log_id': '20240903012307BF16309145430097B1AD'}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 16
#      12     end_date = f"{year}{month_str}{end_day_str}"
#      14     print(f"---- {start_date} to {end_date}----")
# ---> 16     status_code = query_api_video(endpoint_name=endpoint_name, fields=fields,
#      17           query=query, cursor=cursor, start_date=start_date,
#      18           end_date=end_date, save_folder=video_folder)
#      19 print('\n')
#
# Cell In[26], line 33, in query_api_video(endpoint_name, fields, query, cursor, start_date, end_date, save_folder)
#      30 if cursor != 0:
#      31     query_body.update({"search_id": search_id,
#      32                        "cursor": cursor})
# ---> 33 search_id, has_more, cursor, samples, status_code = make_request_video(endpoint, query_body, query_params, headers, save_folder)
#      35 with open(f"./download_logs_{start_date}_{end_date}_{search_id}", "a") as f:
#      36     f.write(f"{cursor}\t{has_more}\t{samples}\t{search_id}\t{status_code}\n")
#
# Cell In[25], line 31, in make_request_video(endpoint, query_body, query_params, headers, save_folder)
#      29         print("Error code", response.status_code)
#      30         print(response.json())
# ---> 31         return query_body["search_id"], False, query_body["cursor"], str(response.json()), status_code
#      33 status_code = response.status_code
#      35 # extracting information for pagination
#
# KeyError: 'search_id'

# %%
status_code = 200
year=2024; month=7; start_day=1; end_day=31

while status_code != 429:
    month_str = '0'+str(month) if month<10 else str(month)
    start_day_str = '0'+str(start_day) if start_day<10 else str(start_day)
    end_day_str = '0'+str(end_day) if end_day<10 else str(end_day)

    start_date = f"{year}{month_str}{start_day_str}"
    end_date = f"{year}{month_str}{end_day_str}"
    
    status_code = query_api_video(endpoint_name=endpoint_name, fields=fields, 
              query=query, cursor=cursor, start_date=start_date, 
              end_date=end_date, save_folder=video_folder)
    # start_day += 1
    # end_day += 1
    break
# Out:
# 100	True	76	7410188393734247467	200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 12
#       9 start_date = f"{year}{month_str}{start_day_str}"
#      10 end_date = f"{year}{month_str}{end_day_str}"
# ---> 12 status_code = query_api_video(endpoint_name=endpoint_name, fields=fields,
#      13           query=query, cursor=cursor, start_date=start_date,
#      14           end_date=end_date, save_folder=video_folder)
#      15 # start_day += 1
#      16 # end_day += 1
#      17 break
#
# Cell In[5], line 39, in query_api_video(endpoint_name, fields, query, cursor, start_date, end_date, save_folder)
#      36         f.write(f"{cursor}\t{has_more}\t{samples}\t{search_id}\t{status_code}\n")
#      38     print(f"{cursor}\t{has_more}\t{samples}\t{search_id}\t{status_code}")
# ---> 39     time.sleep(5)
#      41 return status_code
#
# KeyboardInterrupt:
