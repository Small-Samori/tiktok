# %%
import pandas as pd
import re, os, pickle
import gensim
import gensim.corpora as corpora
from tqdm import tqdm
import spacy

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

def remove_short_text(data_path):
    data = pd.read_csv(data_path, encoding='utf-8')
    data = data.dropna(subset=['text'])
    data = data.rename(columns={'text': 'message', 'id':'message_id'})
    data = data.reset_index()
    
    threshold = 3
    data['message_split'] = [i.split(' ') for i in data['message']]
    lengths = [len(i) for i in data['message_split']]
    
    drop_ids = [i for i in range(len(lengths)) if lengths[i] < threshold]
    data = data.drop(drop_ids)
    data = data.drop(['message_split', 'index'], axis=1)
    data = data.reset_index().drop(['index'], axis=1) 

    return data

# %%
def process_and_tokenize(data_text):
    data_text = [re.sub('\S*@\S*\s?', '', sent) for sent in data_text] # remove emails
    data_text = [re.sub('\+?\d[\d .-]{8,}\d', '', sent) for sent in data_text] #remove phone numbers
    data_text = [re.sub('\s+', ' ', sent) for sent in data_text] # remove newlines
    data_text = [re.sub("\'", "", sent) for sent in data_text] # remove single quotes

    tokenized_data_text = [gensim.utils.simple_preprocess(str(sent), deacc=True) for sent in data_text]

    return tokenized_data_text

# %%
def ngram_and_lemmatize(tokenized_data_text, make_bigram=True, make_trigram=False, 
                        allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):

    bigram = gensim.models.Phrases(tokenized_data_text, min_count=5, threshold=100)
    trigram = gensim.models.Phrases(bigram[tokenized_data_text], threshold=100) 

    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)
    
    data_text = [[word for word in text if word not in stop_words] for text in tokenized_data_text]
    
    if make_bigram:
        data_text = [bigram_mod[sent] for sent in tqdm(data_text, desc="Making Bigrams ...")]

    if make_bigram and make_trigram:
        data_text = [trigram_mod[bigram_mod[sent]] for sent in tqdm(data_text, desc="Making Trigrams ...")]

    lemm_data_text = []
    
    nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])
    for sent in tqdm(data_text, desc="Lemmatizing ..."):
        doc = nlp(" ".join(sent)) 
        lemm_data_text.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
        
    return lemm_data_text

# %%
data_path = "../combined_comments_3.csv"
csv_name = data_path.split("/")[-1]
save_dir = csv_name.split(".")[0]
save_path = f"./{save_dir}"

df = remove_short_text(data_path)
tokenized_data_text = process_and_tokenize(df.message)

# %%
lemmatized_data_text = ngram_and_lemmatize(tokenized_data_text)
# Out:
# Making Bigrams ...: 100%|██████████| 68076/68076 [00:01<00:00, 36331.14it/s]
# Lemmatizing ...: 100%|██████████| 68076/68076 [02:59<00:00, 378.66it/s]

# %%
ids_to_drop = [i for i in range(len(lemmatized_data_text)) if len(lemmatized_data_text[i]) == 0]
lemmatized_data_text_dropped = [i for i in lemmatized_data_text if len(i) != 0]

df_dropped = df.drop(ids_to_drop).reset_index()
df_dropped = df_dropped.drop(['index'], axis=1)

# %%
id2word = corpora.Dictionary(lemmatized_data_text_dropped)
corpus = [id2word.doc2bow(text) for text in lemmatized_data_text_dropped]

# %%
if not os.path.exists(save_path):
    os.mkdir(save_path)

df_dropped.to_csv(f"{save_path}/df_dropped.csv", index=False)

with open(f"{save_path}/lemmatized_data_text_dropped.pickle", "wb") as f:
    pickle.dump(lemmatized_data_text_dropped, f)

with open(f"{save_path}/id2word.pickle", "wb") as f:
    pickle.dump(id2word, f)

with open(f"{save_path}/corpus.pickle", "wb") as f:
    pickle.dump(corpus, f)

# %%
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:5]]
# Out:
# [[('fentanyl', 1), ('idea', 1), ('many', 1), ('use', 1)],
#  [('child', 1), ('spiritual', 1), ('warefare', 1)],
#  [('havevto', 1), ('never', 1), ('pain', 1), ('pray', 1), ('understand', 1)],
#  [('much', 1), ('thank', 1)],
#  [('day', 1), ('miss', 1), ('momma', 1), ('spending', 1), ('visit', 1)]]

# %%
from gensim.models import CoherenceModel
import gensim
from tqdm import tqdm
import pickle, os

# %%
def compute_coherence_values(id2word, corpus, texts, limit, start=5, step=10):
    home = os.getenv("HOME")
    os.environ.update({'MALLET_HOME':r'/home/users/iasamori/tiktok/mallet-2.0.8/'})
    mallet_path = f"{home}/tiktok/mallet-2.0.8/bin/mallet"
    
    coherence_values = []
    nums = []
    for num_topics in tqdm(range(start, limit, step)):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word, random_seed=43)
        
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=id2word, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        
        nums.append(num_topics)
        
    return nums, coherence_values

# %%
save_path = "./combined_comments_3"

with open(f"{save_path}/lemmatized_data_text_dropped.pickle", "rb") as f:
    lemmatized_data_text_dropped = pickle.load(f)

with open(f"{save_path}/id2word.pickle", "rb") as f:
    id2word = pickle.load(f)

with open(f"{save_path}/corpus.pickle", "rb") as f:
    corpus = pickle.load(f)

# %%
nums, coherence_values = compute_coherence_values(id2word, corpus, lemmatized_data_text_dropped, limit=13)
# Out:
# 100%|██████████| 1/1 [00:47<00:00, 47.46s/it]

# %%
nums, coherence_values
# Out:
# ([5], [0.29243067500645054])

# %%
bigram = gensim.models.Phrases(data_text_tokenized, min_count=5, threshold=100)
trigram = gensim.models.Phrases(bigram[data_text_tokenized], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_text_tokenized[5]]])
# Out:
# [['many',
#   'of',
#   'them',
#   'have',
#   'no',
#   'idea',
#   'they',
#   'are',
#   'using',
#   'fentanyl'],
#  ['your', 'children', 'are', 'spiritual', 'warefare'],
#  ['pray', 'they', 'never', 'havevto', 'understand', 'our', 'pain'],
#  ['how', 'ya', 'doing'],
#  ['thank', 'you', 'so', 'much'],
#  ['happy',
#   'birthday',
#   'jackson',
#   'hope',
#   'you',
#   're',
#   'spending',
#   'it',
#   'visiting',
#   'your',
#   'momma',
#   'that',
#   'misses',
#   'you',
#   'more',
#   'and',
#   'more',
#   'every',
#   'day'],
#  ['this', 'absolutely', 'agree'],
#  ['so', 'sorry', 'and', 'on', 'his', 'bday'],
#  ['so', 'so', 'sorry'],
#  ['sorry', 'for', 'your', 'loss'],
#  ['wish',
#   'could',
#   'ask',
#   'you',
#   'to',
#   'reassure',
#   'me',
#   'it',
#   'gets',
#   'easier',
#   'but',
#   'youre',
#   'years',
#   'ahead',
#   'of',
#   'me',
#   'it',
#   'still',
#   'hurts',
#   'good',
#   'luck',
#   'in',
#   'your',
#   'new',
#   'place',
#   'need',
#   'to',
#   'let',
#   'go'],
#  ['of',
#   'the',
#   'farm',
#   'raised',
#   'my',
#   'kids',
#   'on',
#   'with',
#   'my',
#   'husband',
#   'he',
#   'died',
#   'in',
#   'car',
#   'wreck',
#   'in',
#   'it',
#   'was',
#   'hard',
#   'losing',
#   'him',
#   'but',
#   'my',
#   'son',
#   'is',
#   'infinitely',
#   'harder'],
#  ['jackson',
#   'know',
#   'you',
#   'put',
#   'all',
#   'you',
#   'had',
#   'every',
#   'bit',
#   'into',
#   'loving',
#   'your',
#   'boy'],
#  ['his',
#   'message',
#   'to',
#   'you',
#   'how',
#   'proud',
#   'of',
#   'you',
#   'im',
#   'so',
#   'sorry',
#   'my',
#   'babygirl',
#   'was',
#   'born',
#   'departed',
#   'only',
#   'wait',
#   'for',
#   'the',
#   'day',
#   'hv',
#   'her',
#   'in',
#   'my',
#   'arms',
#   'agai'],
#  ['sure',
#   'do',
#   'love',
#   'that',
#   'sweet',
#   'angel',
#   'still',
#   'doesn',
#   'feel',
#   'real'],
#  ['didn',
#   'realize',
#   'we',
#   'were',
#   'the',
#   'same',
#   'age',
#   'just',
#   'months',
#   'apart'],
#  ['so', 'heartbreaking', 'prayers', 'and', 'thoughts'],
#  ['and',
#   'we',
#   'have',
#   'to',
#   'acknowledge',
#   'that',
#   'there',
#   'is',
#   'risk',
#   'every',
#   'time',
#   'you',
#   'allow',
#   'doctor',
#   'to',
#   'inject',
#   'anything',
#   'into',
#   'your',
#   'spine'],
#  ['it',
#   'makes',
#   'me',
#   'so',
#   'mad',
#   'that',
#   'they',
#   're',
#   'pushing',
#   'extremely',
#   'expensive',
#   'non',
#   'fda',
#   'approved',
#   'non',
#   'effective',
#   'injections',
#   'it',
#   'about',
#   'the',
#   'money',
#   'and',
#   'it',
#   'wrong'],
#  ['isn',
#   'it',
#   'so',
#   'bad',
#   'it',
#   'time',
#   'just',
#   'just',
#   'encourage',
#   'and',
#   'empower',
#   'all',
#   'of',
#   'our',
#   'pain',
#   'people',
#   'the',
#   'best',
#   'way',
#   'we',
#   'can',
#   'and',
#   'help',
#   'them',
#   'avoid',
#   'the',
#   'big',
#   'ones',
#   'that',
#   'are',
#   'realbad'],
#  ['they',
#   'also',
#   'make',
#   'you',
#   'sign',
#   'away',
#   'your',
#   'ability',
#   'to',
#   'sue',
#   'them',
#   'gotta',
#   'find',
#   'their',
#   'intake',
#   'forms'],
#  ['exactly',
#   'it',
#   'clearly',
#   'noted',
#   'on',
#   'google',
#   'fda',
#   'they',
#   'caused',
#   'more',
#   'harm',
#   'than',
#   'good',
#   'for',
#   'me'],
#  ['it',
#   'been',
#   'rough',
#   'we',
#   've',
#   'been',
#   'in',
#   'heat',
#   'dome',
#   'here',
#   'but',
#   'still',
#   'struggling',
#   'with',
#   'high',
#   'pain',
#   'be',
#   'patient',
#   'with',
#   'yourself'],
#  ['injections', 'made', 'my', 'pain', 'worse'],
#  ['thank',
#   'you',
#   'kim',
#   'for',
#   'all',
#   'the',
#   'information',
#   'you',
#   'give',
#   'us'],
#  ['they',
#   'also',
#   'all',
#   'contain',
#   'mercury',
#   'as',
#   'the',
#   'preservative',
#   'asked',
#   'my',
#   'dr',
#   'for',
#   'the',
#   'insert',
#   'of',
#   'the',
#   'injection',
#   'and',
#   'pointed',
#   'out',
#   'why',
#   'was',
#   'refusing',
#   'the',
#   'injections'],
#  ['well', 'said'],
#  ['you',
#   're',
#   'very',
#   'welcome',
#   'if',
#   'can',
#   'help',
#   'just',
#   'one',
#   'person',
#   'it',
#   'all',
#   'worth',
#   'it'],
#  ['you', 'are', 'right', 'on', 'the', 'money'],
#  ['and',
#   'they',
#   'can',
#   'end',
#   'up',
#   'doing',
#   'more',
#   'damage',
#   'in',
#   'the',
#   'long',
#   'run',
#   'the',
#   'first',
#   'few',
#   'that',
#   'got',
#   'helped',
#   'but',
#   'after',
#   'times',
#   'they',
#   'didnt',
#   'do',
#   'much',
#   'the',
#   'ones',
#   'in',
#   'my',
#   'feet',
#   'omg'],
#  ['yes',
#   'maam',
#   'im',
#   'so',
#   'sorry',
#   'for',
#   'your',
#   'experience',
#   'know',
#   'what',
#   'that',
#   'feels',
#   'like'],
#  ['reached',
#   'the',
#   'max',
#   'amount',
#   'of',
#   'shots',
#   'could',
#   'get',
#   'and',
#   'the',
#   'last',
#   'ones',
#   'were',
#   'so',
#   'painful',
#   'they',
#   'made',
#   'me',
#   'shout',
#   'out',
#   'in',
#   'pain',
#   'and',
#   'cry',
#   'instantly',
#   'havent',
#   'been',
#   'the',
#   'same'],
#  ['shouldnt',
#   'have',
#   'even',
#   'bothered',
#   'getting',
#   'the',
#   'last',
#   'ones',
#   'cuz',
#   'they',
#   'werent',
#   'really',
#   'helpful',
#   'but',
#   'wasnt',
#   'expecting',
#   'what',
#   'happened',
#   'that',
#   'day'],
#  ['dont',
#   'apologize',
#   'for',
#   'getting',
#   'upset',
#   'hun',
#   'its',
#   'hard',
#   'topic',
#   'and',
#   'you',
#   'had',
#   'tough',
#   'day',
#   'on',
#   'top',
#   'of',
#   'everything',
#   'sending',
#   'hugs'],
#  ['took',
#   'certain',
#   'muscle',
#   'relaxer',
#   'on',
#   'off',
#   'for',
#   'more',
#   'than',
#   'yrs',
#   'now',
#   'cant',
#   'get',
#   'any',
#   'prescribed',
#   'it',
#   'me',
#   'because',
#   'its',
#   'addictive',
#   'it',
#   'works',
#   'deeper'],
#  ['which', 'muscle', 'relaxer'],
#  ['am', 'so', 'sorry', 'for', 'your', 'experience', 'mine', 'was', 'similar'],
#  ['more',
#   'at',
#   'bone',
#   'level',
#   'where',
#   'as',
#   'most',
#   'muscle',
#   'relaxers',
#   'work',
#   'towards',
#   'the',
#   'top',
#   'of',
#   'the',
#   'muscle',
#   'how',
#   'do',
#   'get',
#   'them',
#   'to',
#   'give',
#   'me',
#   'something',
#   'that',
#   'helps',
#   'me'],
#  ['yes',
#   'that',
#   'why',
#   'try',
#   'to',
#   'raise',
#   'awareness',
#   'and',
#   'correct',
#   'misinformation',
#   'the',
#   'stigma',
#   'is',
#   'awful',
#   'for',
#   'anyone',
#   'on',
#   'cs'],
#  ['drs',
#   'get',
#   'paid',
#   'per',
#   'injection',
#   'and',
#   'rx',
#   'they',
#   'prescribe',
#   'wish',
#   'holistic',
#   'drs',
#   'we',
#   're',
#   'less',
#   'expensive',
#   'or',
#   'insurance',
#   'pays'],
#  ['omg',
#   'fully',
#   'believe',
#   'that',
#   'wanna',
#   'do',
#   'more',
#   'research',
#   'what',
#   'happens',
#   'when',
#   'you',
#   'get',
#   'cortisone',
#   'in',
#   'the',
#   'body',
#   'for',
#   'extended',
#   'periods',
#   'of',
#   'time'],
#  ['injections', 'gave', 'me', 'seizures'],
#  ['was',
#   'referring',
#   'to',
#   'soma',
#   'mg',
#   'could',
#   'take',
#   'up',
#   'day',
#   'tizinidine',
#   'mg',
#   'did',
#   'nothing',
#   'me'],
#  ['far',
#   've',
#   'had',
#   'good',
#   'luck',
#   'with',
#   'it',
#   'before',
#   'it',
#   'was',
#   'on',
#   'methacarbomal',
#   'robaxin',
#   'it',
#   'worked',
#   'for',
#   'me',
#   'for',
#   'years',
#   'too'],
#  ['ahh',
#   'on',
#   'baclofen',
#   'times',
#   'day',
#   'just',
#   'increased',
#   'to',
#   'mg',
#   'day',
#   'from',
#   'mg'],
#  ['it',
#   'can',
#   'even',
#   'be',
#   'an',
#   'implant',
#   'that',
#   'releases',
#   'set',
#   'amount',
#   'at',
#   'time',
#   'called',
#   'baclofen',
#   'pump',
#   'my',
#   'bf',
#   'with',
#   'cp',
#   'has',
#   'one',
#   'now',
#   'it',
#   'doesn',
#   'work',
#   'for',
#   'everyone',
#   'but',
#   'so'],
#  ['soma',
#   'mg',
#   'day',
#   'sometime',
#   'wouldnt',
#   'take',
#   'it',
#   'at',
#   'all',
#   'sometime',
#   'would',
#   'take',
#   'it',
#   'there',
#   'were',
#   'times',
#   'would',
#   'go',
#   'months',
#   'without',
#   'refill'],
#  ['havent',
#   'tried',
#   'that',
#   'ill',
#   'look',
#   'it',
#   'up',
#   'maybe',
#   'talk',
#   'to',
#   'my',
#   'doctor'],
#  ['no',
#   'the',
#   'nerve',
#   'block',
#   'epidural',
#   'injections',
#   'which',
#   'are',
#   'also',
#   'not',
#   'fda',
#   'approved',
#   'always',
#   'ask',
#   'for',
#   'the',
#   'drug',
#   'insert',
#   'sheets',
#   'so',
#   'can',
#   'research',
#   'it'],
#  ['for',
#   'me',
#   'soma',
#   'brought',
#   'my',
#   'quality',
#   'of',
#   'life',
#   'back',
#   'it',
#   'the',
#   'only',
#   'that',
#   'has',
#   'ever',
#   'worked',
#   'me'],
#  ['thank', 'you', 'my', 'dear'],
#  ['yup',
#   'and',
#   'it',
#   'should',
#   'never',
#   'be',
#   'that',
#   'way',
#   'that',
#   'fear',
#   'is',
#   'terrible',
#   'but',
#   'it',
#   'is',
#   'liberating',
#   'to',
#   'get',
#   'out',
#   'of',
#   'that',
#   'struggle',
#   'with',
#   'the',
#   'right',
#   'doctors'],
#  ['can',
#   'relate',
#   'to',
#   'being',
#   'gaslight',
#   'and',
#   'being',
#   'afraid',
#   'of',
#   'being',
#   'ignored',
#   'by',
#   'your',
#   'dr',
#   'so',
#   'what',
#   'little',
#   'care',
#   'you',
#   'get',
#   'will',
#   'be',
#   'taken',
#   'away'],
#  ['that',
#   'is',
#   'so',
#   'many',
#   'levels',
#   'of',
#   'wrong',
#   'swear',
#   'they',
#   'ask',
#   'those',
#   'questions',
#   'just',
#   'so',
#   'they',
#   'can',
#   'rate',
#   'you',
#   'higher',
#   'for',
#   'the',
#   'addiction',
#   'scale'],
#  ['needless',
#   'to',
#   'say',
#   'he',
#   'was',
#   'floored',
#   'also',
#   'accused',
#   'him',
#   'of',
#   'worrying',
#   'more',
#   'about',
#   'covering',
#   'his',
#   'ass',
#   'than',
#   'patient',
#   'care'],
#  ['applaud',
#   'you',
#   'for',
#   'that',
#   'you',
#   'did',
#   'what',
#   'was',
#   'right',
#   'for',
#   'you'],
#  ['good',
#   'for',
#   'you',
#   'im',
#   'just',
#   'soooo',
#   'exhausted',
#   'from',
#   'arguing',
#   'about',
#   'my',
#   'quality',
#   'of',
#   'life',
#   'literally',
#   'asked',
#   'my',
#   'last',
#   'dr',
#   'if',
#   'he',
#   'ever',
#   'was',
#   'in',
#   'my',
#   'situation'],
#  ['he',
#   'did',
#   'too',
#   'made',
#   'me',
#   'describe',
#   'what',
#   'that',
#   'trauma',
#   'made',
#   'me',
#   'feel',
#   'like',
#   'all',
#   'to',
#   'just',
#   'gaslight',
#   'me',
#   'and',
#   'tell',
#   'me',
#   'that',
#   'mindful',
#   'imagery',
#   'was',
#   'my',
#   'solution'],
#  ['thank', 'you', 'so', 'much'],
#  ['thank', 'you', 'so', 'much', 'my', 'dear'],
#  ['my',
#   'therapist',
#   'at',
#   'the',
#   'time',
#   'contacted',
#   'him',
#   'over',
#   'it',
#   'too',
#   'was',
#   'never',
#   'told',
#   'of',
#   'the',
#   'outcome'],
#  ['youre', 'very', 'welcome', 'my', 'friend'],
#  ['omg',
#   'using',
#   'your',
#   'childhood',
#   'drama',
#   'against',
#   'you',
#   'is',
#   'such',
#   'low',
#   'blow',
#   'wow',
#   'im',
#   'pissed',
#   'for',
#   'you'],
#  ['many', 'of', 'my', 'dr', 'reports', 'have', 'been', 'fabricated'],
#  ['thank', 'you', 'so', 'much', 'trying', 'my', 'best'],
#  ['am',
#   'very',
#   'glad',
#   'that',
#   'it',
#   'does',
#   'help',
#   'you',
#   'continue',
#   'what',
#   'works',
#   'for',
#   'you',
#   'im',
#   'glad',
#   'you',
#   'have',
#   'that',
#   'ability'],
#  ['yes',
#   'ma',
#   'am',
#   'telling',
#   'our',
#   'own',
#   'stories',
#   'and',
#   'what',
#   'we',
#   've',
#   'learned',
#   'from',
#   'them',
#   'is',
#   'huge',
#   'one'],
#  ['cortisone',
#   'injections',
#   'is',
#   'they',
#   'why',
#   'they',
#   'aren',
#   'fda',
#   'approved'],
#  ['photograph',
#   'waterfalls',
#   'and',
#   'nature',
#   'again',
#   'after',
#   'years',
#   'of',
#   'not',
#   'being',
#   'able',
#   'to',
#   'but',
#   'we',
#   'are',
#   'going',
#   'to',
#   'try',
#   'tomorrow',
#   'too'],
#  ['this',
#   'one',
#   'was',
#   'tough',
#   'one',
#   'little',
#   'bit',
#   'low',
#   'spoons',
#   'high',
#   'pain',
#   'day',
#   'and',
#   'missed',
#   'goal',
#   'today',
#   'the',
#   'one',
#   'weekend',
#   'that',
#   'could',
#   'was',
#   'ready',
#   'to',
#   'go',
#   'photograph'],
#  ['what', 'adverse', 'effects'],
#  ['does',
#   'anyone',
#   'know',
#   'how',
#   'to',
#   'find',
#   'this',
#   'type',
#   'of',
#   'palliative',
#   'care',
#   'in',
#   'houston',
#   'in',
#   'texas',
#   'and',
#   'houston',
#   'every',
#   'time',
#   'look',
#   'it',
#   'up',
#   'find',
#   'hospice'],
#  ['wanna',
#   'do',
#   'which',
#   'one',
#   'and',
#   'also',
#   'want',
#   'to',
#   'guess',
#   'that',
#   'you',
#   'may',
#   'be',
#   'taking',
#   'about',
#   'tizanidine'],
#  ['ah',
#   'yeah',
#   'soma',
#   'didn',
#   'do',
#   'anything',
#   'for',
#   'me',
#   'flexeril',
#   'is',
#   'kinda',
#   'junk',
#   'to',
#   'me',
#   'tizanidine',
#   'worked',
#   'well',
#   'for',
#   'me',
#   'for',
#   'while',
#   'but',
#   'was',
#   'causing',
#   'adverse',
#   'effects'],
#  ['do', 'agree', 'with', 'you'],
#  ['the',
#   'nerve',
#   'block',
#   'epidural',
#   'injections',
#   'believe',
#   'are',
#   'cortisone',
#   'shots',
#   'as',
#   'well',
#   'at',
#   'least',
#   'that',
#   'is',
#   'what',
#   'got'],
#  ['you', 're', 'very', 'welcome'],
#  ['would',
#   'be',
#   'printing',
#   'them',
#   'out',
#   'and',
#   'showing',
#   'them',
#   'what',
#   'inaccurate',
#   'and',
#   'have',
#   'it',
#   'amended',
#   'because',
#   'of',
#   'future',
#   'mds',
#   'that',
#   'will',
#   'see',
#   'the',
#   'records'],
#  ['even',
#   'if',
#   'you',
#   'pocketed',
#   'it',
#   'that',
#   'money',
#   'was',
#   'to',
#   'make',
#   'your',
#   'life',
#   'easier',
#   'during',
#   'hard',
#   'time'],
#  ['terrible',
#   'that',
#   'you',
#   'have',
#   'to',
#   'deal',
#   'with',
#   'that',
#   'fool',
#   'during',
#   'such',
#   'sad',
#   'time'],
#  ['glad',
#   'you',
#   'are',
#   'speaking',
#   'up',
#   'for',
#   'the',
#   'sake',
#   'of',
#   'your',
#   'family',
#   'glad',
#   'to',
#   'hear',
#   'you',
#   'have',
#   'nothing',
#   'to',
#   'do',
#   'with',
#   'him',
#   'stay',
#   'strong'],
#  ['they', 'see', 'the', 'facts', 'reality', 'meant'],
#  ['this',
#   'man',
#   'is',
#   'horrible',
#   'father',
#   'feel',
#   'for',
#   'his',
#   'children',
#   'what',
#   'shame'],
#  ['know',
#   'it',
#   'nice',
#   'that',
#   'my',
#   'kids',
#   'are',
#   'old',
#   'enough',
#   'to',
#   'see',
#   'the',
#   'fact',
#   'that',
#   'they',
#   'see',
#   'in',
#   'front',
#   'of',
#   'their',
#   'eyes',
#   'and',
#   'not',
#   'believe',
#   'the',
#   'bullshit',
#   'lies'],
#  ['forgot',
#   'to',
#   'mention',
#   'that',
#   'he',
#   'told',
#   'the',
#   'kids',
#   'that',
#   'he',
#   'should',
#   'be',
#   'able',
#   'to',
#   'get',
#   'some',
#   'of',
#   'that',
#   'money',
#   'the',
#   'audacity'],
#  ['unbelievable',
#   'some',
#   'people',
#   'like',
#   'to',
#   'be',
#   'the',
#   'hero',
#   'in',
#   'situations',
#   'you',
#   'have',
#   'proff',
#   'so',
#   'doesnt',
#   'he',
#   'look',
#   'so',
#   'silly'],
#  ['never',
#   'question',
#   'momma',
#   'like',
#   'you',
#   'wouldn',
#   'take',
#   'care',
#   'of',
#   'business'],
#  ['yrs', 'old', 'he', 'needs', 'to', 'cover', 'his', 'son', 'wow'],
#  ['really',
#   'sad',
#   'for',
#   'you',
#   'that',
#   'you',
#   're',
#   'having',
#   'to',
#   'deal',
#   'with',
#   'all',
#   'the',
#   'extra',
#   'bs'],
#  ['lord', 'how', 'know', 'too', 'well'],
#  ['and',
#   'now',
#   'getting',
#   'pissed',
#   'because',
#   'your',
#   'ex',
#   'should',
#   've',
#   'gotten',
#   'the',
#   'money',
#   'then',
#   'presented',
#   'you',
#   'with',
#   'it',
#   'not',
#   'with',
#   'could',
#   've'],
#  ['good',
#   'for',
#   'you',
#   'what',
#   'piece',
#   'of',
#   'work',
#   'how',
#   'dare',
#   'he',
#   'as',
#   'if',
#   'you',
#   'aren',
#   'going',
#   'through',
#   'enough',
#   'people',
#   'are',
#   'vile',
#   'sorry',
#   'you',
#   'had',
#   'to',
#   'contend',
#   'with',
#   'that'],
#  ['he', 'is', 'sick', 'sick', 'person'],
#  ['thank', 'you', 'for', 'your', 'kindness'],
#  ['no', 'need', 'to', 'jade', 'justify', 'argue', 'defend', 'explain', 'done'],
#  ['cant',
#   'believe',
#   'he',
#   'took',
#   'him',
#   'off',
#   'the',
#   'insurance',
#   'because',
#   'he',
#   'told',
#   'the',
#   'truth',
#   'very',
#   'sad'],
#  ['he',
#   'loser',
#   'that',
#   'goes',
#   'to',
#   'show',
#   'how',
#   'much',
#   'he',
#   'cares',
#   'about',
#   'his',
#   'children'],
#  ['that',
#   'so',
#   'sad',
#   'he',
#   'just',
#   'grasping',
#   'at',
#   'straws',
#   'your',
#   'kids',
#   'are',
#   'lucky',
#   'to',
#   'have',
#   'you',
#   'and',
#   'they',
#   'know',
#   'the',
#   'sacrifices',
#   'you',
#   'have',
#   'made',
#   'for',
#   'them',
#   'he',
#   'irrelevant'],
#  ['im',
#   'happy',
#   'got',
#   'help',
#   'not',
#   'easie',
#   'but',
#   'boy',
#   'your',
#   'ex',
#   'needs',
#   'help',
#   'and',
#   'god',
#   'in',
#   'his',
#   'life',
#   'wow',
#   'glad',
#   'you',
#   'got',
#   'away',
#   'from',
#   'him',
#   'also'],
#  ['so',
#   'sorry',
#   'have',
#   'to',
#   'deal',
#   'with',
#   'such',
#   'money',
#   'was',
#   'given',
#   'to',
#   'you',
#   'to',
#   'use',
#   'as',
#   'you',
#   'see',
#   'fit',
#   'he',
#   'should',
#   'have',
#   'zero',
#   'say',
#   'he',
#   'should',
#   've',
#   'stepped',
#   'up',
#   'contributed'],
#  ['fkkkkk', 'him', 'don', 'even', 'waste', 'your', 'breath', 'on', 'him'],
#  ['and',
#   'that',
#   'man',
#   'should',
#   'know',
#   'this',
#   'if',
#   'hes',
#   'went',
#   'to',
#   'funeral',
#   'home',
#   'we',
#   'buried',
#   'dad',
#   'yrs',
#   'ago',
#   'its',
#   'crazy',
#   'high',
#   'to',
#   'cremate',
#   'or',
#   'bury',
#   'loved',
#   'one'],
#  ['wow', 'like', 'you', 'need', 'this', 'crap', 'right', 'now'],
#  ['that', 'exactly', 'what', 'he', 'wanted'],
#  ['thank', 'you'],
#  ['amen', 'because', 'you', 'already', 'know', 'much', 'love'],
#  ['im',
#   'so',
#   'glad',
#   'you',
#   'were',
#   'able',
#   'to',
#   'pay',
#   'for',
#   'everything',
#   'this',
#   'man',
#   'sounds',
#   'like',
#   'total',
#   'ass',
#   'how',
#   'could',
#   'he',
#   'do',
#   'his',
#   'son',
#   'that',
#   'way',
#   'cant',
#   'imagine',
#   'how',
#   'he',
#   'has',
#   'done'],
#  ['you',
#   'are',
#   'brave',
#   'strong',
#   'woman',
#   'admire',
#   'your',
#   'courage',
#   'to',
#   'have',
#   'voice'],
#  ['thank', 'you'],
#  ['some',
#   'people',
#   'are',
#   'just',
#   'real',
#   'pos',
#   'sorry',
#   'he',
#   'is',
#   'even',
#   'putting',
#   'you',
#   'through',
#   'this',
#   'absolutely',
#   'disgusting'],
#  ['moving', 'forward'],
#  ['you',
#   'cannot',
#   'tell',
#   'him',
#   'how',
#   'to',
#   'feel',
#   'yes',
#   'sure',
#   'he',
#   'loved',
#   'her',
#   'but',
#   'disappointment',
#   'is',
#   'real',
#   'thing'],
#  ['the',
#   'fkn',
#   'nerve',
#   'of',
#   'him',
#   'to',
#   'cut',
#   'his',
#   'son',
#   'off',
#   'tell',
#   'those',
#   'lies',
#   'god',
#   'dont',
#   'like',
#   'ugly',
#   'sir'],
#  ['think',
#   'asking',
#   'begging',
#   'for',
#   'money',
#   'when',
#   'family',
#   'member',
#   'dies',
#   'is',
#   'horrendous',
#   'shame'],
#  ['yeah',
#   'you',
#   'so',
#   'good',
#   'that',
#   'you',
#   'needed',
#   'to',
#   'set',
#   'up',
#   'go',
#   'fund',
#   'me'],
#  ['the',
#   'things',
#   'he',
#   'said',
#   'when',
#   'angel',
#   'was',
#   'at',
#   'the',
#   'hospital',
#   'tells',
#   'me',
#   'he',
#   'piece',
#   'of',
#   'shit',
#   'this',
#   'new',
#   'information',
#   'doesn',
#   'surprise',
#   'me'],
#  ['better',
#   'yet',
#   'such',
#   'good',
#   'soul',
#   'that',
#   'was',
#   'helped',
#   'beyond',
#   'belief',
#   'through',
#   'that',
#   'go',
#   'fund',
#   'me'],
#  ['we',
#   'love',
#   'you',
#   'angel',
#   'wanted',
#   'to',
#   'make',
#   'sure',
#   'you',
#   'were',
#   'able',
#   'to',
#   'lay',
#   'her',
#   'rest',
#   'the',
#   'way',
#   'she',
#   'deserves',
#   'these',
#   'people',
#   'just',
#   'make',
#   'me',
#   'sick'],
#  ['you',
#   'shouldnt',
#   'have',
#   'to',
#   'justify',
#   'any',
#   'of',
#   'your',
#   'actions',
#   'to',
#   'him',
#   'or',
#   'publicly',
#   'on',
#   'social',
#   'media',
#   'if',
#   'your',
#   'conscience',
#   'is',
#   'clear',
#   'you',
#   'dont',
#   'need',
#   'to',
#   'defend',
#   'yourself'],
#  ['what', 'horrible', 'father', 'he', 'is'],
#  ['don',
#   'know',
#   'why',
#   'said',
#   'car',
#   'insurance',
#   'my',
#   'dad',
#   'is',
#   'the',
#   'same',
#   'way',
#   'it',
#   'all',
#   'about',
#   'control',
#   'get',
#   'that',
#   'man',
#   'out',
#   'of',
#   'all',
#   'your',
#   'lives',
#   'it',
#   'sad',
#   'but'],
#  ['he', 'will', 'only', 'get', 'worse', 'with', 'age'],
#  ['what',
#   'dead',
#   'beat',
#   'dad',
#   'with',
#   'that',
#   'kind',
#   'of',
#   'loss',
#   'he',
#   'should',
#   'shut',
#   'up',
#   'be',
#   'man',
#   'and',
#   'support',
#   'his',
#   'kids',
#   'no',
#   'questions',
#   'asked',
#   'hate',
#   'narcissists'],
#  ['think',
#   'the',
#   'way',
#   'youre',
#   'disrespecting',
#   'speaking',
#   'to',
#   'grieving',
#   'mother',
#   'is',
#   'horrendous',
#   'do',
#   'better',
#   'hope',
#   'you',
#   'never',
#   'find',
#   'yourself',
#   'in',
#   'situation',
#   'like',
#   'this'],
#  ['foundation',
#   'of',
#   'tt',
#   'is',
#   'interactive',
#   'watched',
#   'multiple',
#   'videos',
#   'admired',
#   'you',
#   'never',
#   'giving',
#   'up',
#   'tracking',
#   'her',
#   'down',
#   'disagreed',
#   'on',
#   'this',
#   'you',
#   'went',
#   'loco'],
#  ['shane', 'in', 'you', 'not', 'the', 'place', 'for', 'this'],
#  ['that',
#   'behavior',
#   'is',
#   'disgusting',
#   'and',
#   'so',
#   'is',
#   'your',
#   'current',
#   'behavior',
#   'posting',
#   'on',
#   'things',
#   'when',
#   'you',
#   'can',
#   'just',
#   'scroll',
#   'seek',
#   'therapy'],
#  ['speak',
#   'your',
#   'truth',
#   'but',
#   'sad',
#   'as',
#   'well',
#   'father',
#   'would',
#   'do',
#   'that',
#   'as',
#   'well',
#   'prayers'],
#  ['do',
#   'you',
#   'not',
#   'have',
#   'anything',
#   'better',
#   'to',
#   'do',
#   'if',
#   'you',
#   'don',
#   'understand',
#   'our',
#   'story',
#   'and',
#   'are',
#   'going',
#   'off',
#   'of',
#   'one',
#   'video',
#   'that',
#   'your',
#   'problem'],
#  ['he', 'dirtbag'],
#  ['birds', 'of', 'feather', 'flock', 'together'],
#  ['it', 'okay'],
#  ['it',
#   'disgusting',
#   'to',
#   'see',
#   'how',
#   'so',
#   'called',
#   'parents',
#   'go',
#   'to',
#   'social',
#   'media',
#   'grow',
#   'up'],
#  ['so',
#   'sorry',
#   'your',
#   'going',
#   'through',
#   'this',
#   'praying',
#   'for',
#   'you',
#   'and',
#   'the',
#   'family'],
#  ['how',
#   'is',
#   'showing',
#   'receipts',
#   'from',
#   'funeral',
#   'fighting',
#   'for',
#   'your',
#   'daughter',
#   'im',
#   'so',
#   'confused'],
#  ['to',
#   'make',
#   'it',
#   'clear',
#   'will',
#   'always',
#   'fight',
#   'for',
#   'her',
#   'be',
#   'her',
#   'voice',
#   'if',
#   'you',
#   'as',
#   'parent',
#   'wouldn',
#   'do',
#   'that',
#   'that',
#   'on',
#   'you'],
#  ['ma',
#   'am',
#   'also',
#   'lost',
#   'my',
#   'daughter',
#   'in',
#   'car',
#   'accident',
#   'so',
#   'incredibly',
#   'sorry',
#   'for',
#   'your',
#   'loss',
#   'saddened',
#   'that',
#   'you',
#   'have',
#   'to',
#   'deal',
#   'with',
#   'him'],
#  ['that',
#   'where',
#   'you',
#   're',
#   'wrong',
#   'you',
#   'only',
#   'watch',
#   'videos',
#   'you',
#   'choose',
#   'to',
#   'watch',
#   'sheep',
#   'always',
#   'think',
#   'people',
#   'that',
#   'speak',
#   'the',
#   'truth',
#   'are',
#   'crazy'],
#  ['no',
#   'my',
#   'choice',
#   'is',
#   'never',
#   'say',
#   'an',
#   'unkind',
#   'word',
#   'about',
#   'their',
#   'father',
#   'regardless',
#   'so',
#   'im',
#   'bad',
#   'parent',
#   'since',
#   'im',
#   'not',
#   'on',
#   'social',
#   'media',
#   'bashing',
#   'their',
#   'dad'],
#  ['ohhh',
#   'got',
#   'it',
#   'now',
#   'you',
#   're',
#   'man',
#   'probably',
#   'the',
#   'same',
#   'type',
#   'father',
#   'my',
#   'ex',
#   'is',
#   'this',
#   'made',
#   'my',
#   'day',
#   'thank',
#   'you'],
#  ['so',
#   'happy',
#   'you',
#   'found',
#   'your',
#   'voice',
#   'from',
#   'this',
#   'truly',
#   'sorry',
#   'for',
#   'your',
#   'loss'],
#  ['what', 'bastard'],
#  ['he',
#   'seems',
#   'like',
#   'piece',
#   'oh',
#   'shit',
#   'sounds',
#   'like',
#   'my',
#   'ex',
#   'why',
#   'is',
#   'it',
#   'that',
#   'when',
#   'the',
#   'kids',
#   'realize',
#   'or',
#   'calls',
#   'them',
#   'out',
#   'they',
#   'get',
#   'cut',
#   'off',
#   'soo',
#   'sad'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['life',
#   'is',
#   'beautiful',
#   'don',
#   'forget',
#   'to',
#   'stop',
#   'and',
#   'smell',
#   'the',
#   'roses',
#   'on',
#   'this',
#   'wonderful',
#   'day',
#   'may',
#   'you',
#   'and',
#   'your',
#   'family',
#   'be',
#   'blessed',
#   'today',
#   'and',
#   'forever',
#   'amen'],
#  ['im', 'sorry', 'you', 'went', 'through', 'this'],
#  ['so', 'much', 'trauma', 'all', 'around'],
#  ['its', 'horrible', 'this', 'went', 'on', 'while', 'you', 'were', 'grieving'],
#  ['fact', 'girl', 'myself'],
#  ['cant', 'believe', 'people', 'put', 'all', 'their', 'shit', 'on', 'media'],
#  ['condolences', 'to', 'you', 'and', 'family'],
#  ['your',
#   'ex',
#   'is',
#   'real',
#   'butt',
#   'head',
#   'thank',
#   'goodness',
#   'he',
#   'is',
#   'no',
#   'longer',
#   'in',
#   'your',
#   'life'],
#  ['keep', 'your', 'head', 'up', 'queen'],
#  ['can',
#   'sympathize',
#   'with',
#   'you',
#   'am',
#   'so',
#   'sorry',
#   'for',
#   'your',
#   'loss',
#   'my',
#   'son',
#   'is',
#   'presently',
#   'in',
#   'prison'],
#  ['thank',
#   'you',
#   'for',
#   'your',
#   'compassion',
#   'many',
#   'blessings',
#   'to',
#   'you',
#   'and',
#   'your',
#   'son'],
#  ['we', 'have', 'spent', 'so', 'many', 'hours', 'listening', 'to', 'morphine'],
#  ['especially', 'on', 'thursdays'],
#  ['love', 'all', 'morphine', 'totally', 'underrated'],
#  ['ohhhhh', 'man', 'this', 'is', 'such', 'great', 'album'],
#  ['that', 'nod', 'is', 'what', 'gets', 'me', 'every', 'time'],
#  ['take', 'in', 'that', 'video', 'is', 'from', 'edmonton', 'canada'],
#  ['the',
#   'fact',
#   'that',
#   'he',
#   'canadian',
#   'just',
#   'pulls',
#   'it',
#   'all',
#   'together'],
#  ['thought', 'had', 'crack', 'on', 'my', 'screen', 'for', 'sec'],
#  ['bro',
#   'scared',
#   'me',
#   'sm',
#   'thought',
#   'some',
#   'file',
#   'got',
#   'corrupted',
#   'cause',
#   'that',
#   'line',
#   'on',
#   'the',
#   'vid'],
#  ['not',
#   'only',
#   'his',
#   'voice',
#   'his',
#   'entire',
#   'body',
#   'was',
#   'trembling',
#   'ik',
#   'he',
#   'was',
#   'sweating',
#   'bet',
#   'he',
#   'cried',
#   'after',
#   'this',
#   'public',
#   'display',
#   'of',
#   'idiocy'],
#  ['he', 'was', 'seething'],
#  ['yeah', 'idk', 'wtf', 'that', 'is', 'get', 'on', 'this', 'please'],
#  ['am', 'confusion', 'arent', 'they', 'in', 'canada'],
#  ['encumbered', 'lead', 'walk'],
#  ['just',
#   'going',
#   'to',
#   'hope',
#   'that',
#   'desantis',
#   'supporters',
#   'get',
#   'visited',
#   'by',
#   'three',
#   'spirits',
#   'like',
#   'ebeneezer',
#   'scrooge'],
#  ['even', 'funnier', 'he', 'canadian'],
#  ['he',
#   'doesnt',
#   'even',
#   'know',
#   'where',
#   'he',
#   'is',
#   'or',
#   'whats',
#   'going',
#   'on',
#   'he',
#   'still',
#   'manages',
#   'to',
#   'scream',
#   'at',
#   'people',
#   'boomer',
#   'racism',
#   'etc',
#   'is',
#   'impressive',
#   'in',
#   'how',
#   'terrifying',
#   'it',
#   'is'],
#  ['poor',
#   'boys',
#   'gonna',
#   'go',
#   'out',
#   'elvis',
#   'style',
#   'with',
#   'that',
#   'temper'],
#  ['the', 'recreation'],
#  ['canadian',
#   'politics',
#   'has',
#   'truly',
#   'devolved',
#   'the',
#   'past',
#   'couple',
#   'years',
#   'since',
#   'harper',
#   'lol',
#   'the',
#   'word',
#   'woke',
#   'is',
#   'commonly',
#   'used',
#   'in',
#   'the',
#   'house',
#   'of',
#   'commons'],
#  ['he', 'from', 'my', 'country', 'bro', 'can', 'even', 'do', 'that'],
#  ['he', 'needs', 'to', 'stamp', 'his', 'little', 'feet'],
#  ['thought', 'my', 'phone', 'was', 'broken'],
#  ['semmed', 'more', 'like', 'an', 'endorsment'],
#  ['and', 'they', 'call', 'us', 'the', 'npcs'],
#  ['another', 'incredible', 'tiktok', 'king', 'frenchy', 'well', 'done'],
#  ['they',
#   'should',
#   'let',
#   'him',
#   'run',
#   'so',
#   'we',
#   'can',
#   'check',
#   'the',
#   'hard',
#   'drives',
#   'of',
#   'all',
#   'his',
#   'voters'],
#  ['why',
#   'are',
#   'these',
#   'types',
#   'of',
#   'boomers',
#   'all',
#   'built',
#   'the',
#   'same',
#   'lol'],
#  ['funnier', 'when', 'you', 'dont', 'live', 'there', 'fml'],
#  ['his',
#   'entire',
#   'voter',
#   'base',
#   'can',
#   'be',
#   'crippled',
#   'by',
#   'faulty',
#   'set',
#   'of',
#   'stairs'],
#  ['anyone',
#   'who',
#   'votes',
#   'for',
#   'desantis',
#   'is',
#   'most',
#   'likely',
#   'pedophile',
#   'and',
#   'you',
#   'cant',
#   'convince',
#   'me',
#   'otherwise'],
#  ['the', 'head', 'nod', 'is', 'funny', 'every', 'time', 'see', 'it'],
#  ['desantis',
#   'main',
#   'base',
#   'has',
#   'wobbly',
#   'voices',
#   'and',
#   'even',
#   'wobblier',
#   'knees',
#   'that',
#   'hilarious'],
#  ['exactly', 'it', 'painful', 'to', 'see'],
#  ['thought',
#   'that',
#   'line',
#   'in',
#   'the',
#   'screen',
#   'was',
#   'my',
#   'phone',
#   'bro'],
#  ['this', 'should', 'be', 'viral'],
#  ['thank',
#   'you',
#   'for',
#   'doing',
#   'this',
#   'everyone',
#   'should',
#   'have',
#   'had',
#   'the',
#   'chance',
#   'to',
#   'know',
#   'how',
#   'amazing',
#   'she',
#   'was'],
#  ['we',
#   'gotta',
#   'keep',
#   'pushing',
#   'to',
#   'save',
#   'lives',
#   'let',
#   'people',
#   'know',
#   'recovery',
#   'is',
#   'possible',
#   'and',
#   'how',
#   'dangerous',
#   'things',
#   'have',
#   'gotten'],
#  ['am', 'so', 'sorry', 'brother'],
#  ['im', 'so', 'sorry', 'brother'],
#  ['sending', 'love', 'hugs', 'for', 'everyone'],
#  ['this',
#   'is',
#   'malisa',
#   'daughter',
#   'its',
#   'been',
#   'while',
#   'but',
#   'time',
#   'dont',
#   'matter'],
#  ['so', 'sorry', 'brother'],
#  ['holding', 'you', 'up', 'in', 'love', 'and', 'light'],
#  ['love', 'you', 'malisa'],
#  ['im', 'soo', 'soo', 'sorry', 'for', 'ur', 'loss'],
#  ['damn', 'im', 'so', 'sorry'],
#  ['ooooh', 'chris', 'im', 'so', 'sorry'],
#  ['how', 'do', 'untag', 'myself', 'on', 'this', 'please'],
#  ['outlining',
#   'child',
#   'in',
#   'your',
#   'life',
#   'whether',
#   'yours',
#   'or',
#   'others',
#   'is',
#   'very',
#   'rough',
#   'thing',
#   'to',
#   'do',
#   'so',
#   'im',
#   'here',
#   'for',
#   'you'],
#  ['this', 'is', 'my', 'good', 'friends', 'daughter'],
#  ['im',
#   'so',
#   'sorry',
#   'for',
#   'your',
#   'heart',
#   'spencers',
#   'mum',
#   'dec',
#   'fentyal',
#   'od',
#   'poison',
#   'drug',
#   'supply'],
#  ['love',
#   'you',
#   'mema',
#   'just',
#   'wanted',
#   'you',
#   'know',
#   'you',
#   're',
#   'not',
#   'alone',
#   'love',
#   'you',
#   'will',
#   'cry',
#   'with',
#   'you',
#   'love',
#   'you',
#   'malinda'],
#  ['way',
#   'to',
#   'hong',
#   'hunny',
#   'so',
#   'sorry',
#   'may',
#   'she',
#   'rest',
#   'in',
#   'sweet',
#   'peace'],
#  ['my',
#   'beautiful',
#   'mother',
#   'in',
#   'law',
#   'said',
#   'rosary',
#   'for',
#   'us',
#   'last',
#   'night',
#   'was',
#   'so',
#   'broken',
#   'and',
#   'she',
#   'lifted',
#   'my',
#   'spirit',
#   'and',
#   'love',
#   'her',
#   'with',
#   'all',
#   'my',
#   'heart',
#   'my',
#   'baby',
#   'mom',
#   'my',
#   'mom',
#   'for',
#   'over',
#   'years'],
#  ['que', 'diosito', 'los', 'quide', 'at', 'todos'],
#  ['so',
#   'sorry',
#   'can',
#   'imagine',
#   'what',
#   'that',
#   'feel',
#   'of',
#   'loss',
#   'would',
#   'be',
#   'praying',
#   'for',
#   'you',
#   'and',
#   'the',
#   'family'],
#  ['im', 'so', 'sorry', 'for', 'your', 'loss'],
#  ['tad', 'too', 'much', 'heat'],
#  ['finally',
#   'got',
#   'my',
#   'account',
#   'verified',
#   'and',
#   'my',
#   'btc',
#   'withdrawal',
#   'fixed',
#   'by',
#   'on',
#   'instagram'],
#  ['why',
#   'is',
#   'it',
#   'so',
#   'cheap',
#   'now',
#   'why',
#   'would',
#   'price',
#   'be',
#   'going',
#   'down',
#   'it',
#   'makes',
#   'no',
#   'sense',
#   'unless',
#   'it',
#   'by',
#   'design',
#   'to',
#   'harm',
#   'population'],
#  ['no', 'shame'],
#  ['congrats', 'on', 'one', 'month'],
#  ['mad', 'respect', 'for', 'keeping', 'it'],
#  ['and',
#   'so',
#   'am',
#   'but',
#   'we',
#   'got',
#   'this',
#   'as',
#   'long',
#   'as',
#   'we',
#   'keep',
#   'trying',
#   'feel',
#   'that',
#   'all',
#   'that',
#   'matters'],
#  ['congratulations',
#   'got',
#   'this',
#   'been',
#   'here',
#   'time',
#   'after',
#   'time',
#   'still',
#   'struggling',
#   'proud',
#   'of'],
#  ['you',
#   'aint',
#   'never',
#   'lied',
#   'cold',
#   'turkied',
#   'mgs',
#   'and',
#   'thought',
#   'was',
#   'going',
#   'to',
#   'die',
#   'was',
#   'in',
#   'agony',
#   'because',
#   'left',
#   'nj',
#   'to',
#   'go',
#   'to',
#   'ga',
#   'and',
#   'didnt',
#   'know',
#   'they',
#   'had'],
#  ['you',
#   'got',
#   'this',
#   'my',
#   'beautiful',
#   'friend',
#   'promise',
#   'the',
#   'hardest',
#   'part',
#   'is',
#   'all',
#   'the',
#   'feelings',
#   'we',
#   'numb',
#   'out',
#   'never',
#   'give',
#   'up'],
#  ['understand', 'ive', 'been', 'there'],
#  ['keep', 'shinning', 'queen'],
#  ['wish', 'could', 'be', 'part', 'of', 'your', 'life'],
#  ['congrats',
#   'baby',
#   'stay',
#   'on',
#   'top',
#   'it',
#   'hard',
#   'but',
#   'you',
#   'got',
#   'this',
#   'it',
#   'raw',
#   'emotions',
#   'and',
#   'they',
#   'are',
#   'valid',
#   'keep',
#   'going',
#   'do',
#   'not',
#   'stop'],
#  ['have',
#   'to',
#   'be',
#   'strong',
#   'baby',
#   'take',
#   'everything',
#   'day',
#   'at',
#   'time',
#   'promise',
#   'it',
#   'gets',
#   'better'],
#  ['one',
#   'day',
#   'at',
#   'time',
#   'god',
#   'got',
#   'you',
#   'congratulations',
#   'blessings',
#   'on',
#   'your',
#   'journey'],
#  ['got', 'this', 'girl', 'be', 'the', 'same', 'way'],
#  ['nothing',
#   'can',
#   'be',
#   'done',
#   'over',
#   'night',
#   'you',
#   'stay',
#   'strong',
#   'and',
#   'day',
#   'at',
#   'time',
#   'you',
#   'got',
#   'this'],
#  ['keep',
#   'going',
#   'baby',
#   'stay',
#   'strong',
#   'my',
#   'sister',
#   'felt',
#   'like',
#   'she',
#   'was',
#   'getting',
#   'addicted',
#   'and',
#   'it',
#   'was',
#   'hard',
#   'for',
#   'her',
#   'to',
#   'get',
#   'off',
#   'them',
#   'you',
#   'got',
#   'this'],
#  ['praying', 'for', 'you'],
#  ['start',
#   'your',
#   'own',
#   'group',
#   'of',
#   'people',
#   'here',
#   'let',
#   'them',
#   'know',
#   'what',
#   'you',
#   'did',
#   'to',
#   'get',
#   'where',
#   'are',
#   'now',
#   'congratulations',
#   'on',
#   'getting',
#   'as',
#   'far',
#   'as',
#   'you',
#   'have',
#   'already',
#   'im',
#   'proud',
#   'of',
#   'you',
#   'beautiful'],
#  ['you',
#   'got',
#   'this',
#   'praying',
#   'for',
#   'your',
#   'strength',
#   'and',
#   'god',
#   'to',
#   'comfort',
#   'you',
#   'and',
#   'lead',
#   'you',
#   'in',
#   'the',
#   'right',
#   'direction'],
#  ['you', 'got', 'this'],
#  ['baby',
#   'your',
#   'addiction',
#   'is',
#   'for',
#   'lifetime',
#   'so',
#   'that',
#   'being',
#   'said',
#   'you',
#   'can',
#   'only',
#   'take',
#   'it',
#   'day',
#   'at',
#   'time',
#   'just',
#   'pray',
#   'and',
#   'be',
#   'strong',
#   'for',
#   'being',
#   'sober'],
#  ['congratulations', 'on', 'your', 'month'],
#  ['you',
#   'got',
#   'this',
#   'to',
#   'come',
#   'on',
#   'social',
#   'media',
#   'and',
#   'tell',
#   'your',
#   'story',
#   'it',
#   'mental',
#   'think',
#   'that',
#   'all',
#   'don',
#   'give',
#   'up',
#   'you',
#   'can',
#   'do',
#   'this'],
#  ['na',
#   'is',
#   'the',
#   'place',
#   'to',
#   'be',
#   'they',
#   'have',
#   'many',
#   'resources',
#   'that',
#   'can',
#   'help',
#   'you',
#   'keep',
#   'going',
#   'sis'],
#  ['my',
#   'god',
#   'know',
#   'what',
#   'you',
#   'going',
#   'through',
#   'keep',
#   'fighting',
#   'hunny',
#   'find',
#   'what',
#   'works',
#   'for',
#   'you',
#   'and',
#   'keep',
#   'working',
#   'the',
#   'program',
#   'are',
#   'suboxone',
#   'hun'],
#  ['she', 'is', 'telling', 'the', 'truth'],
#  ['will',
#   'keep',
#   'you',
#   'in',
#   'my',
#   'prayers',
#   'stay',
#   'strong',
#   'push',
#   'for',
#   'you',
#   'don',
#   'give',
#   'up',
#   'the',
#   'devil',
#   'want',
#   'you',
#   'to',
#   'give',
#   'up',
#   'god',
#   'got',
#   'plan',
#   'for',
#   'you',
#   'iam',
#   'proud',
#   'of',
#   'you',
#   'and',
#   'your',
#   'beautiful',
#   'just',
#   'keep',
#   'loving',
#   'yourself',
#   'you',
#   'can',
#   'do',
#   'it'],
#  ['praying', 'for', 'you'],
#  ['sending', 'prayers', 'you', 'got', 'this', 'boo'],
#  ['baby',
#   'know',
#   'god',
#   'trust',
#   'me',
#   'do',
#   'and',
#   'know',
#   'that',
#   'there',
#   'is',
#   'help'],
#  ['clinic',
#   'there',
#   'so',
#   'had',
#   'to',
#   'tough',
#   'it',
#   'out',
#   'could',
#   'have',
#   'died',
#   'if',
#   'was',
#   'drinking',
#   'higher',
#   'dose'],
#  ['keep',
#   'working',
#   'on',
#   'your',
#   'sobriety',
#   'they',
#   'dont',
#   'have',
#   'different',
#   'na',
#   'meetings',
#   'where',
#   'you',
#   'are',
#   'im',
#   'sorry',
#   'if',
#   'misunderstood',
#   'something'],
#  ['proud', 'of', 'you', 'kyra'],
#  ['praying',
#   'for',
#   'your',
#   'strength',
#   'my',
#   'baby',
#   'got',
#   'this',
#   'take',
#   'it',
#   'one',
#   'day',
#   'at',
#   'time',
#   'that',
#   'all',
#   'you',
#   'can',
#   'do'],
#  ['hey',
#   'beautiful',
#   'the',
#   'mere',
#   'fact',
#   'that',
#   'you',
#   'are',
#   'being',
#   'honest',
#   'about',
#   'what',
#   'you',
#   'are',
#   'dealing',
#   'with',
#   'tells',
#   'me',
#   'you',
#   'got',
#   'this',
#   'and',
#   'god',
#   'got',
#   'you',
#   'stay',
#   'strong',
#   'please',
#   'dont',
#   'go',
#   'back'],
#  ['thank',
#   'you',
#   'for',
#   'sharing',
#   'your',
#   'story',
#   'beautiful',
#   'you',
#   'got',
#   'this',
#   'stay',
#   'strong',
#   'and',
#   'push',
#   'through',
#   'it'],
#  ['baby',
#   'have',
#   'plate',
#   'in',
#   'my',
#   'shoulder',
#   'been',
#   'off',
#   'pain',
#   'meds',
#   'years',
#   'and',
#   'here',
#   'am',
#   'again',
#   'all',
#   'because',
#   'broke',
#   'my',
#   'collarbone',
#   'so',
#   'angry',
#   'with',
#   'myself',
#   'but',
#   'the',
#   'pain',
#   'is',
#   'serious',
#   'one',
#   'day',
#   'at',
#   'time'],
#  ['these',
#   'rehabs',
#   'not',
#   'good',
#   'they',
#   'give',
#   'you',
#   'other',
#   'drugs',
#   'to',
#   'take',
#   'went',
#   'to',
#   'georgia',
#   'recovery',
#   'they',
#   'come',
#   'pick',
#   'you',
#   'up',
#   'and',
#   'take',
#   'you',
#   'there',
#   'but',
#   'they',
#   'gave',
#   'me',
#   'even',
#   'stronger',
#   'drugs',
#   'when',
#   'got',
#   'there',
#   'just',
#   'pray',
#   'love'],
#  ['just',
#   'found',
#   'something',
#   'else',
#   'to',
#   'do',
#   'because',
#   'it',
#   'will',
#   'pass',
#   'and',
#   'every',
#   'time',
#   'you',
#   'think',
#   'of',
#   'it',
#   'do',
#   'something',
#   'else'],
#  ['congratulation',
#   'sweetie',
#   'day',
#   'at',
#   'time',
#   'and',
#   'dont',
#   'beat',
#   'yourself',
#   'up',
#   'its',
#   'process',
#   'dm',
#   'me',
#   'we',
#   'can',
#   'talk',
#   'ok',
#   'have',
#   'been',
#   'there',
#   'myself',
#   'be',
#   'prove',
#   'of',
#   'yourself'],
#  ['you', 'got', 'it', 'princess'],
#  ['keep',
#   'your',
#   'self',
#   'around',
#   'positive',
#   'people',
#   'who',
#   'wants',
#   'better',
#   'im',
#   'proud',
#   'of',
#   'you'],
#  ['congratulations',
#   'keep',
#   'up',
#   'the',
#   'great',
#   'work',
#   'take',
#   'it',
#   'one',
#   'day',
#   'at',
#   'time'],
#  ['hey', 'you', 'are', 'human', 'be', 'kind', 'to', 'yourself'],
#  ['all',
#   'of',
#   'us',
#   'give',
#   'us',
#   'round',
#   'of',
#   'applause',
#   'for',
#   'being',
#   'here',
#   'still'],
#  ['recovery', 'out', 'loud'],
#  ['just',
#   'lost',
#   'friend',
#   'again',
#   'we',
#   'got',
#   'to',
#   'start',
#   'sharing',
#   'too',
#   'help',
#   'each',
#   'other',
#   'someone',
#   'needs',
#   'to',
#   'hear',
#   'your',
#   'story',
#   'saved',
#   'life',
#   'is',
#   'better',
#   'then',
#   'another',
#   'loss'],
#  ['do', 'it', 'start', 'with', 'are', 'selfs', 'first'],
#  ['thank', 'you', 'you', 'are', 'my', 'inspiration'],
#  ['love', 'this', 'wedorecover'],
#  ['girl',
#   'try',
#   'to',
#   'get',
#   'more',
#   'patients',
#   'on',
#   'hospice',
#   'as',
#   'hh',
#   'we',
#   'get',
#   'ton',
#   'that',
#   'should',
#   'be',
#   'on',
#   'hospice',
#   'services'],
#  ['just',
#   'did',
#   'travel',
#   'contract',
#   'in',
#   'ltc',
#   'snf',
#   'am',
#   'going',
#   'back',
#   'to',
#   'home',
#   'care'],
#  ['looked',
#   'at',
#   'prison',
#   'contract',
#   'recently',
#   'was',
#   'like',
#   'it',
#   'can',
#   'be',
#   'worst',
#   'than',
#   'this',
#   'ltc',
#   'love',
#   'my',
#   'patients',
#   'so',
#   'knowing',
#   'that',
#   'they',
#   'get',
#   'garbage',
#   'care',
#   'like',
#   'that',
#   'hurts',
#   'my',
#   'soul',
#   'home',
#   'care',
#   'is',
#   'hands',
#   'down',
#   'the',
#   'best'],
#  ['going',
#   'to',
#   'crack',
#   'that',
#   'joke',
#   'to',
#   'my',
#   'don',
#   'on',
#   'my',
#   'last',
#   'day'],
#  ['brag', 'it', 'up', 'you', 're', 'entitled'],
#  ['we', 'll', 'take', 'em'],
#  ['girl',
#   'worked',
#   'at',
#   'prison',
#   'for',
#   'my',
#   'first',
#   'job',
#   'because',
#   'saw',
#   'how',
#   'my',
#   'sisters',
#   'first',
#   'job',
#   'in',
#   'ltc',
#   'was',
#   'nope'],
#  ['agree', 'at', 'least', 'the', 'ratios', 'are', 'somewhat', 'better'],
#  ['so', 'sorry', 'lots', 'of', 'prayers'],
#  ['so',
#   'sorry',
#   'for',
#   'your',
#   'loss',
#   'my',
#   'heart',
#   'and',
#   'prayers',
#   'go',
#   'out',
#   'to',
#   'you',
#   'and',
#   'your',
#   'family',
#   'god',
#   'bless',
#   'you',
#   'all',
#   'so',
#   'sad'],
#  ['message',
#   'coletechz',
#   'on',
#   'instagram',
#   'hes',
#   'good',
#   'person',
#   'and',
#   'has',
#   'helped',
#   'lot',
#   'of',
#   'ppl',
#   'including',
#   'myself',
#   'just',
#   'be',
#   'honest'],
#  ['double', 'the', 'cup'],
#  ['that', 'hard', 'asf'],
#  ['this',
#   'is',
#   'exactly',
#   'what',
#   'the',
#   'dea',
#   'cdc',
#   'fda',
#   'doj',
#   'intended',
#   'short',
#   'all',
#   'life',
#   'saving',
#   'rx',
#   'pain',
#   'meds',
#   'drive',
#   'us',
#   'to',
#   'the',
#   'streets',
#   'or',
#   'to',
#   'ending',
#   'ourselves'],
#  ['thank',
#   'goodness',
#   'for',
#   'kasey',
#   'found',
#   'pm',
#   'dr',
#   'they',
#   'told',
#   'me',
#   'they',
#   'have',
#   'pharm',
#   'in',
#   'house',
#   'and',
#   'across',
#   'the',
#   'street',
#   'the',
#   'pharmacy',
#   'is',
#   'aware',
#   'of',
#   'the',
#   'high',
#   'mme',
#   'they',
#   'prescribe',
#   'and',
#   'so',
#   'far',
#   'for',
#   'years',
#   'havent',
#   'had',
#   'issues'],
#  ['they',
#   'order',
#   'hydromorophone',
#   'er',
#   'for',
#   'me',
#   'every',
#   'days',
#   'so',
#   'far',
#   'have',
#   'not',
#   'had',
#   'issue',
#   'but',
#   'im',
#   'waiting',
#   'im',
#   'sure',
#   'its',
#   'coming',
#   'scary',
#   'times'],
#  ['would',
#   'suggest',
#   'going',
#   'to',
#   'hospital',
#   'pharmacy',
#   'that',
#   'serves',
#   'the',
#   'public',
#   'as',
#   'well',
#   'those',
#   'pharmacies',
#   'will',
#   'get',
#   'it',
#   'first'],
#  ['think',
#   'we',
#   'all',
#   'need',
#   'to',
#   'talk',
#   'to',
#   'our',
#   'pain',
#   'management',
#   'doctors',
#   'about',
#   'an',
#   'emergency',
#   'plan',
#   'before',
#   'this',
#   'happens',
#   'to',
#   'us',
#   'it',
#   'happened',
#   'to',
#   'my',
#   'husband',
#   'twice',
#   've',
#   'been',
#   'lucky',
#   'so',
#   'far',
#   'but',
#   'know',
#   'things',
#   'are',
#   'going',
#   'bad'],
#  ['don',
#   'consider',
#   'it',
#   'weird',
#   'as',
#   'they',
#   'have',
#   'cut',
#   'production',
#   'even',
#   'more',
#   'than',
#   'they',
#   'did',
#   'last',
#   'year',
#   'this',
#   'is',
#   'intentional',
#   'in',
#   'my',
#   'eyes'],
#  ['if',
#   'you',
#   'could',
#   'to',
#   'the',
#   'fda',
#   'shortage',
#   'page',
#   'there',
#   'is',
#   'no',
#   'record',
#   'of',
#   'this',
#   'med',
#   'being',
#   'short',
#   'please',
#   'report',
#   'it',
#   'to',
#   'them',
#   'maybe',
#   'if',
#   'enough',
#   'of',
#   'us',
#   'report',
#   'they',
#   'will',
#   'acknowledge',
#   'that',
#   'this',
#   'is',
#   'problem'],
#  ['tried',
#   'to',
#   'get',
#   'them',
#   'to',
#   'do',
#   'day',
#   'supply',
#   'since',
#   'they',
#   'had',
#   'it',
#   'she',
#   'didn',
#   'just',
#   'the',
#   'of',
#   'them',
#   'but',
#   'hopefully',
#   'someone',
#   'else',
#   'is',
#   'able',
#   'to',
#   'get',
#   'their',
#   'meds',
#   'too'],
#  ['my',
#   'doctor',
#   'has',
#   'plan',
#   'for',
#   'dealing',
#   'with',
#   'medication',
#   'shortages',
#   'we',
#   've',
#   'had',
#   'to',
#   'change',
#   'dosage',
#   'amounts',
#   'change',
#   'to',
#   'other',
#   'pharmacies',
#   'whatever',
#   'works'],
#  ['nope',
#   'hospital',
#   'pharmacies',
#   'are',
#   'having',
#   'shortages',
#   'of',
#   'many',
#   'different',
#   'types',
#   'of',
#   'meds',
#   'not',
#   'just',
#   'pain',
#   'meds'],
#  ['believe',
#   'you',
#   'it',
#   'horseshit',
#   'that',
#   'you',
#   'have',
#   'to',
#   'have',
#   'money',
#   'to',
#   'get',
#   'quality',
#   'care',
#   'my',
#   'husband',
#   'pays',
#   'well',
#   'over',
#   'per',
#   'month',
#   'and',
#   'his',
#   'job',
#   'matches',
#   'it',
#   'how',
#   'is',
#   'that',
#   'even',
#   'thing'],
#  ['same', 'really', 'appreciate', 'kasey'],
#  ['have',
#   'you',
#   'tried',
#   'kratom',
#   'know',
#   'it',
#   'may',
#   'not',
#   'seem',
#   'like',
#   'it',
#   'but',
#   'it',
#   'works'],
#  ['exactly',
#   'no',
#   'shortages',
#   'at',
#   'the',
#   'white',
#   'house',
#   'pharmacy',
#   'all',
#   'drugs',
#   'available',
#   'on',
#   'request'],
#  ['can',
#   'only',
#   'imagine',
#   'how',
#   'tough',
#   'that',
#   'is',
#   'on',
#   'you',
#   'every',
#   'one',
#   'of',
#   'us',
#   'are',
#   'struggling',
#   'with',
#   'unique',
#   'circumstances',
#   'but',
#   'we',
#   'are',
#   'all',
#   'connected',
#   'by',
#   'care',
#   'for',
#   'one',
#   'another'],
#  ['wish',
#   'that',
#   'were',
#   'the',
#   'case',
#   'there',
#   'really',
#   'are',
#   'terrible',
#   'shortages',
#   'of',
#   'so',
#   'many',
#   'meds',
#   'even',
#   'not',
#   'pain',
#   'meds',
#   'albuterol',
#   'epinephrine',
#   'mental',
#   'health',
#   'drugs',
#   'it',
#   'bad'],
#  ['nor',
#   'are',
#   'we',
#   'you',
#   'may',
#   'have',
#   'had',
#   'surgeries',
#   'cancer',
#   'but',
#   'intractable',
#   'pain',
#   'that',
#   'only',
#   'responds',
#   'to',
#   'pain',
#   'meds',
#   'is',
#   'something',
#   'you',
#   'don',
#   'experience',
#   'or',
#   'you',
#   'wouldn',
#   'be',
#   'trolling',
#   'chronically',
#   'ill',
#   'pain',
#   'pts',
#   'what'],
#  ['make',
#   'sure',
#   'to',
#   'have',
#   'mine',
#   'in',
#   'stock',
#   'every',
#   'month',
#   'not',
#   'everyone',
#   'is',
#   'having',
#   'hard',
#   'time'],
#  ['have',
#   'had',
#   'no',
#   'problem',
#   'getting',
#   'my',
#   'hydromorphone',
#   'the',
#   'last',
#   'months',
#   'in',
#   'fact',
#   'last',
#   'summer',
#   'they',
#   'often',
#   'had',
#   'to',
#   'make',
#   'me',
#   'wait',
#   'hours',
#   'for',
#   'it',
#   'would',
#   'apologize',
#   'all',
#   'over',
#   'the',
#   'place',
#   'now',
#   'it',
#   'improved',
#   'they'],
#  ['holy',
#   'shit',
#   'you',
#   're',
#   'right',
#   'just',
#   'looked',
#   'at',
#   'the',
#   'app',
#   'what',
#   'the',
#   'fuck'],
#  ['you',
#   'have',
#   'idea',
#   'what',
#   'it',
#   'like',
#   'living',
#   'in',
#   'intractable',
#   'pain'],
#  ['is', 'it', 'the', 'rhodes', 'or', 'different', 'manufacturer'],
#  ['all',
#   'else',
#   'aside',
#   'need',
#   'to',
#   'be',
#   'good',
#   'mama',
#   'then',
#   'wife',
#   'then',
#   'daughter'],
#  ['these', 'people', 'are', 'jacking', 'you', 'around'],
#  ['wow', 'well', 'kept', 'secret', 'these', 'drug', 'shortages'],
#  ['they',
#   'know',
#   'what',
#   'will',
#   'happen',
#   'if',
#   'we',
#   'dont',
#   'get',
#   'them',
#   'that',
#   'is',
#   'exactly',
#   'what',
#   'they',
#   'want'],
#  ['you',
#   'can',
#   'thank',
#   'the',
#   'dea',
#   'for',
#   'the',
#   'cut',
#   'they',
#   'just',
#   'don',
#   'get',
#   'it',
#   'even',
#   'when',
#   'we',
#   'the',
#   'ppl',
#   'chimed',
#   'in'],
#  ['got',
#   'tired',
#   'of',
#   'the',
#   'struggle',
#   'and',
#   'went',
#   'on',
#   'suboxone',
#   'it',
#   'seriously',
#   'helps',
#   'with',
#   'the',
#   'pain',
#   'and',
#   'keeps',
#   'you',
#   'from',
#   'getting',
#   'super',
#   'sick'],
#  ['weird',
#   'hawaii',
#   'just',
#   'had',
#   'news',
#   'report',
#   'on',
#   'them',
#   'having',
#   'nothing',
#   'for',
#   'pain',
#   'meds'],
#  ['yup',
#   'and',
#   'it',
#   'only',
#   'going',
#   'to',
#   'get',
#   'worse',
#   'unfortunately',
#   'scared'],
#  ['ive',
#   'been',
#   'forced',
#   'to',
#   'suffer',
#   'since',
#   'march',
#   'ill',
#   'be',
#   'december',
#   'now',
#   'ill',
#   'trade',
#   'you',
#   'for',
#   'the',
#   'next',
#   'years',
#   'let',
#   'me',
#   'know',
#   'how',
#   'bad',
#   'you',
#   'feel',
#   'suffering',
#   'while',
#   'hearing',
#   'others',
#   'complain'],
#  ['omg', 'that', 'insane', 'it', 'definitely', 'purposeful', 'too'],
#  ['im',
#   'kratom',
#   'advocate',
#   'and',
#   'rotate',
#   'through',
#   'reputable',
#   'vendors',
#   'and',
#   'yes',
#   'it',
#   'works',
#   'so',
#   'well'],
#  ['also',
#   'walgreens',
#   'cvs',
#   'walmart',
#   'specifically',
#   'are',
#   'the',
#   'worst',
#   'places',
#   'to',
#   'try',
#   'get',
#   'any',
#   'pain',
#   'meds',
#   'rite',
#   'aid',
#   'is',
#   'bankrupt',
#   'so',
#   'we',
#   'cant',
#   'go',
#   'there',
#   'now',
#   'because',
#   'theyve',
#   'closed',
#   'thousands',
#   'of',
#   'stores',
#   'more',
#   'to',
#   'close'],
#  ['my',
#   'sister',
#   'did',
#   'the',
#   'same',
#   'shes',
#   'and',
#   'started',
#   'to',
#   'loose',
#   'all',
#   'her',
#   'teeth',
#   'last',
#   'year',
#   'after',
#   'being',
#   'ok',
#   'subs',
#   'for',
#   'yrs'],
#  ['it',
#   'really',
#   'scary',
#   'so',
#   'glad',
#   'you',
#   'were',
#   'able',
#   'to',
#   'get',
#   'those',
#   'love'],
#  ['remember',
#   'tho',
#   'the',
#   'rich',
#   'the',
#   'famous',
#   'and',
#   'elite',
#   'all',
#   'get',
#   'treatment',
#   'regular',
#   'citizens',
#   'mean',
#   'zero',
#   'my',
#   'case',
#   'is',
#   'especially',
#   'terrible'],
#  ['in',
#   'pa',
#   'unfortunately',
#   'no',
#   'pharmacy',
#   'will',
#   'take',
#   'if',
#   'ur',
# ...
#   'every',
#   'year',
#   'but'],
#  ['you',
#   'really',
#   'need',
#   'to',
#   'open',
#   'your',
#   'eyes',
#   'bro',
#   'youre',
#   'lost'],
#  ['street',
#   'fentanyl',
#   'and',
#   'the',
#   'fentanyl',
#   'used',
#   'in',
#   'hospitals',
#   'or',
#   'in',
#   'medical',
#   'setting',
#   'are',
#   'two',
#   'different',
#   'things',
#   'they',
#   'not',
#   'giving',
#   'illicit',
#   'fentanyl',
#   'in',
#   'the',
#   'hospital'],
#  ['not', 'you', 'brother', 'youre', 'correct', 'was', 'talking', 'to'],
#  ['otherwise',
#   'it',
#   'just',
#   'sounds',
#   'like',
#   'you',
#   'are',
#   'arguing',
#   'feelings',
#   'and',
#   'that',
#   'really',
#   'doesn',
#   'get',
#   'us',
#   'anywhere'],
#  ['well',
#   'that',
#   'is',
#   'interesting',
#   'and',
#   'did',
#   'not',
#   'know',
#   'that',
#   'learning',
#   'new',
#   'things',
#   'all',
#   'the',
#   'time',
#   'thank',
#   'you'],
#  ['was',
#   'supposed',
#   'to',
#   'say',
#   'acetalized',
#   'codine',
#   'yes',
#   'will',
#   'be',
#   'doing',
#   'video',
#   'about',
#   'black',
#   'tar',
#   'and',
#   'how',
#   'it',
#   'came',
#   'about',
#   'similar',
#   'economic',
#   'and',
#   'political',
#   'pressure'],
#  ['they',
#   'lost',
#   'certainly',
#   'do',
#   'grow',
#   'opium',
#   'but',
#   'the',
#   'demand',
#   'is',
#   'so',
#   'high',
#   'for',
#   'fent',
#   'not',
#   'much',
#   'comes',
#   'through',
#   'anymore',
#   'now',
#   'it',
#   'xylazine',
#   'mixed',
#   'with',
#   'it',
#   'even',
#   'worse'],
#  ['love',
#   'to',
#   'hear',
#   'about',
#   'it',
#   'because',
#   'that',
#   'actually',
#   'the',
#   'one',
#   'preferred'],
#  ['interesting', 'agree', 'with', 'you', 'in', 'every', 'way'],
#  ['agreed',
#   'chiba',
#   'is',
#   'real',
#   'problem',
#   'they',
#   'are',
#   'also',
#   'behind',
#   'the',
#   'marxist',
#   'woke',
#   'movement',
#   'so',
#   'they',
#   'are',
#   'definitely',
#   'an',
#   'adversary'],
#  ['feds', 'got', 'rid', 'of', 'all', 'cheep', 'safe', 'pharmaceuticals'],
#  ['possible',
#   'to',
#   'control',
#   'that',
#   'are',
#   'fundamental',
#   'roots',
#   'to',
#   'mental',
#   'emotional',
#   'and',
#   'spiritual',
#   'health',
#   'it',
#   'doesn',
#   'have',
#   'to',
#   'be',
#   'addiction',
#   'it',
#   'can',
#   'be',
#   'proper',
#   'use'],
#  ['soon',
#   'all',
#   'poppies',
#   'will',
#   'produce',
#   'only',
#   'thebaine',
#   'no',
#   'access',
#   'for',
#   'common',
#   'man'],
#  ['yes', 'we', 'will', 'take', 'deeper', 'dive', 'into', 'this', 'absolutely'],
#  ['that',
#   'why',
#   'they',
#   'give',
#   'it',
#   'all',
#   'the',
#   'time',
#   'as',
#   'patch',
#   'and',
#   'given',
#   'during',
#   'almost',
#   'every',
#   'stent',
#   'procedure',
#   'in',
#   'the',
#   'world'],
#  ['hugs', 'everyone', 'daniels', 'mom', 'forever'],
#  ['am', 'so', 'sorry', 'tanya'],
#  ['we',
#   'aint',
#   'hear',
#   'anything',
#   'about',
#   'crack',
#   'until',
#   'death',
#   'and',
#   'incarcerated',
#   'happened'],
#  ['hear', 'you'],
#  ['started',
#   'calling',
#   'right',
#   'after',
#   'lsuren',
#   'died',
#   'my',
#   'town',
#   'told',
#   'me',
#   'no',
#   'money',
#   'for',
#   'public',
#   'service',
#   'announcements'],
#  ['it', 'on', 'the', 'news', 'all', 'the', 'time'],
#  ['listening'],
#  ['lost',
#   'my',
#   'daughter',
#   'and',
#   'my',
#   'son',
#   'recently',
#   'both',
#   'to',
#   'fentanyl',
#   'poisoning',
#   'it',
#   'sickening',
#   'that',
#   'it',
#   'been',
#   'happening',
#   'for',
#   'so',
#   'long'],
#  ['have',
#   'never',
#   'seen',
#   'psa',
#   'jacobs',
#   'mom',
#   'forever',
#   'illicit',
#   'fentanyl',
#   'florida',
#   'thank',
#   'you'],
#  ['it', 'all', 'over', 'the', 'news'],
#  ['zero', 'information'],
#  ['and', 'they', 'still', 'won', 'close', 'borders', 'so', 'sad'],
#  ['yes', 'feel', 'ya'],
#  ['it',
#   'terrible',
#   'sad',
#   'thing',
#   'was',
#   'he',
#   'was',
#   'working',
#   'and',
#   'trying',
#   'to',
#   'straighten',
#   'his',
#   'self',
#   'up',
#   'hate',
#   'that',
#   'this',
#   'all',
#   'happened',
#   'when',
#   'he',
#   'tried',
#   'his',
#   'best',
#   'to',
#   'come',
#   'back'],
#  ['my',
#   'sister',
#   'tried',
#   'for',
#   'years',
#   'to',
#   'straighten',
#   'up',
#   'she',
#   'really',
#   'did',
#   'so',
#   'understand',
#   'your',
#   'pain',
#   'and',
#   'your',
#   'feelings',
#   'went',
#   'the',
#   'same',
#   'with',
#   'my',
#   'sister',
#   'for',
#   'years',
#   'its',
#   'hard',
#   'sometime'],
#  ['thank', 'you', 'for', 'sharing'],
#  ['thank', 'you', 'for', 'posting', 'this'],
#  ['those',
#   'almost',
#   'took',
#   'me',
#   'outta',
#   'here',
#   'as',
#   'well',
#   'as',
#   'my',
#   'daughter',
#   'son',
#   'and',
#   'grandson'],
#  ['im', 'sorry', 'for', 'your', 'loss'],
#  ['keep',
#   'up',
#   'what',
#   'you',
#   'are',
#   'doing',
#   'ms',
#   'pooh',
#   'people',
#   'need',
#   'to',
#   'know',
#   'this',
#   'our',
#   'poor',
#   'kids'],
#  ['please', 'listen', 'young', 'souljas'],
#  ['you',
#   'my',
#   'beautiful',
#   'queen',
#   'are',
#   'in',
#   'my',
#   'prayers',
#   'daily',
#   'so',
#   'sorry',
#   'for',
#   'the',
#   'loss',
#   'of',
#   'your',
#   'angels'],
#  ['my',
#   'daughter',
#   'got',
#   'hold',
#   'of',
#   'dirty',
#   'and',
#   'almost',
#   'died',
#   'praying',
#   'for',
#   'all',
#   'mamas',
#   'who',
#   'lost',
#   'babies',
#   'love',
#   'you'],
#  ['they',
#   'not',
#   'gon',
#   'stop',
#   'most',
#   'people',
#   'doin',
#   'it',
#   'cause',
#   'there',
#   'followers'],
#  ['don', 'do', 'drugs', 'it', 'ain', 'worth', 'it'],
#  ['wow', 'thats', 'some', 'knowledge', 'for', 'yr', 'ass'],
#  ['got',
#   'some',
#   'white',
#   'china',
#   'china',
#   'white',
#   'this',
#   'shit',
#   'stop',
#   'your',
#   'heart',
#   'you',
#   'won',
#   'see',
#   'you',
#   'tonight'],
#  ['facts',
#   'survivor',
#   'so',
#   'called',
#   'friends',
#   'drugged',
#   'me',
#   'and',
#   'flatlined',
#   'times',
#   'years',
#   'ago'],
#  ['my',
#   'mom',
#   'sent',
#   'me',
#   'this',
#   'same',
#   'video',
#   'this',
#   'is',
#   'all',
#   'terrible',
#   'stuff'],
#  ['my',
#   'brother',
#   'in',
#   'law',
#   'died',
#   'of',
#   'this',
#   'year',
#   'ago',
#   'ripjamesdrain'],
#  ['ive',
#   'been',
#   'sober',
#   'two',
#   'years',
#   'and',
#   'wouldnt',
#   'trade',
#   'it',
#   'either',
#   'know',
#   'ppl',
#   'died',
#   'since',
#   'ive',
#   'been',
#   'sober'],
#  ['can',
#   'stress',
#   'this',
#   'enough',
#   'to',
#   'people',
#   'all',
#   'it',
#   'takes',
#   'is',
#   'speck'],
#  ['kirk', 'my', 'heart', 'breaks', 'every', 'time', 'read', 'about', 'evn'],
#  ['thank', 'you', 'for', 'sharing', 'your', 'story'],
#  ['so', 'sorry', 'sending', 'love', 'and', 'prayers'],
#  ['jg', 'for', 'ever', 'prayers', 'for', 'you', 'and', 'your', 'fam'],
#  ['so', 'sorry', 'for', 'your', 'loss'],
#  ['my', 'sincere', 'condolences', 'to', 'you', 'and', 'your', 'family'],
#  ['holding', 'you', 'and', 'your', 'family', 'up', 'to', 'the', 'creator'],
#  ['im', 'so', 'sorry'],
#  ['prayers', 'so', 'sorry'],
#  ['my', 'lil', 'brother', 'did', 'too'],
#  ['so',
#   'sorry',
#   'for',
#   'you',
#   'mamas',
#   'for',
#   'the',
#   'loss',
#   'the',
#   'pain',
#   'god',
#   'give',
#   'you',
#   'strength',
#   'amen'],
#  ['my',
#   'son',
#   'died',
#   'from',
#   'fentanyl',
#   'he',
#   'was',
#   'about',
#   'month',
#   'shy',
#   'of',
#   'turning'],
#  ['feel', 'your', 'pain', 'spencers', 'mum', 'dec', 'fentyal', 'od'],
#  ['sorry', 'for', 'your', 'loss', 'bennys', 'mom', 'forever'],
#  ['am',
#   'so',
#   'sorry',
#   'please',
#   'go',
#   'to',
#   'jw',
#   'org',
#   'to',
#   'learn',
#   'the',
#   'truth',
#   'about',
#   'death',
#   'and',
#   'resurrection',
#   'it',
#   'helped',
#   'us',
#   'and',
#   'gave',
#   'us',
#   'hope'],
#  ['am', 'so', 'sorry', 'for', 'your', 'loss'],
#  ['so', 'sorry', 'about', 'your', 'wonderful', 'sweet', 'son'],
#  ['the',
#   'director',
#   'of',
#   'advanced',
#   'detox',
#   'and',
#   'this',
#   'is',
#   'why',
#   'we',
#   'work',
#   'seven',
#   'god',
#   'bless',
#   'him'],
#  ['im',
#   'so',
#   'sorry',
#   'for',
#   'your',
#   'loss',
#   'too',
#   'loss',
#   'son',
#   'months',
#   'clean',
#   'hate',
#   'fentanyl'],
#  ['xoxo', 'too', 'many', 'lost', 'to', 'young'],
#  ['im',
#   'so',
#   'very',
#   'sorry',
#   'for',
#   'your',
#   'loss',
#   'im',
#   'so',
#   'sad',
#   'this',
#   'drug',
#   'has',
#   'destroyed',
#   'so',
#   'many',
#   'beautiful',
#   'people'],
#  ['so', 'sorry'],
#  ['my', 'dad', 'died', 'from', 'it', 'too', 'god', 'bless', 'you'],
#  ['im', 'so', 'sorry', 'dreasons', 'grandma', 'forever'],
#  ['am',
#   'so',
#   'sorry',
#   'am',
#   'tattooed',
#   'on',
#   'my',
#   'neck',
#   'addiction',
#   'is',
#   'like',
#   'desire',
#   'am',
#   'with',
#   'you',
#   'in',
#   'heaven'],
#  ['junkies', 'are', 'cancer', 'on', 'there', 'families', 'and', 'siciety'],
#  ['damn', 'so', 'sorry'],
#  ['so', 'sorry', 'for', 'your', 'loss'],
#  ['so', 'sorry', 'for', 'your', 'loss'],
#  ['sorry', 'for', 'your', 'loss'],
#  ['sorry', 'for', 'your', 'loss'],
#  ['am', 'so', 'sorry', 'for', 'the', 'lose', 'of', 'ur', 'child'],
#  ['may',
#   'he',
#   'rest',
#   'in',
#   'peace',
#   'so',
#   'sad',
#   'lost',
#   'my',
#   'son',
#   'at',
#   'also',
#   'forever'],
#  ['so',
#   'sorry',
#   'addiction',
#   'is',
#   'awful',
#   'but',
#   'god',
#   'knows',
#   'his',
#   'heart',
#   'we',
#   'may',
#   'be',
#   'sad',
#   'but',
#   'he',
#   'is',
#   'finally',
#   'free'],
#  ['so',
#   'sorry',
#   'my',
#   'son',
#   'has',
#   'months',
#   'and',
#   'that',
#   'is',
#   'one',
#   'of',
#   'my',
#   'biggest',
#   'fears'],
#  ['my',
#   'son',
#   'was',
#   'in',
#   'overdose',
#   'too',
#   'but',
#   'lord',
#   'protect',
#   'him'],
#  ['so', 'very', 'sorry'],
#  ['abstain',
#   'at',
#   'least',
#   'one',
#   'day',
#   'month',
#   'and',
#   'then',
#   'slowly',
#   'increase',
#   'the',
#   'number',
#   'of',
#   'days',
#   'or',
#   'abstain',
#   'every',
#   'day',
#   'is',
#   'easyer',
#   'to',
#   'hold',
#   'on',
#   'than',
#   'every',
#   'day',
#   'while'],
#  ['im', 'so', 'sorry'],
#  ['so', 'sorry'],
#  ['sorry',
#   'for',
#   'your',
#   'loss',
#   'my',
#   'son',
#   'is',
#   'addicted',
#   'to',
#   'fentanyl',
#   'and',
#   'has',
#   'been',
#   'for',
#   'years',
#   'he',
#   'will',
#   'be',
#   'in',
#   'august',
#   'thanks',
#   'for',
#   'sharing',
#   'your',
#   'story'],
#  ['my', 'daughter', 'died', 'on', 'feel', 'your', 'pain'],
#  ['this',
#   'bad',
#   'feeling',
#   'lost',
#   'my',
#   'baby',
#   'girl',
#   'off',
#   'the',
#   'same',
#   'she',
#   'was',
#   'beautiful',
#   'young',
#   'soul'],
#  ['sorry',
#   'for',
#   'yr',
#   'loss',
#   'hopefully',
#   'this',
#   'video',
#   'will',
#   'help',
#   'someone',
#   'out',
#   'their',
#   'realise',
#   'it',
#   'time',
#   'to',
#   'stop',
#   'bless',
#   'you',
#   'and',
#   'your',
#   'family'],
#  ['so',
#   'sorry',
#   'my',
#   'brother',
#   'as',
#   'well',
#   'eric',
#   'forever',
#   'the',
#   'pain',
#   'of',
#   'missing',
#   'them',
#   'hurts',
#   'it',
#   'empty',
#   'feeling',
#   'that',
#   'we',
#   'all',
#   'have',
#   'to',
#   'endure',
#   'everyday',
#   'prayers'],
#  ['so', 'sorry'],
#  ['so', 'sorry', 'for', 'your', 'loss'],
#  ['so',
#   'very',
#   'sorry',
#   'my',
#   'son',
#   'died',
#   'of',
#   'fentanyl',
#   'overdose',
#   'from',
#   'some',
#   'girl',
#   'who',
#   'gave',
#   'him',
#   'painkiller',
#   'will',
#   'never',
#   'get',
#   'over',
#   'it',
#   'he',
#   'was',
#   'only'],
#  ['so',
#   'very',
#   'sorry',
#   'for',
#   'your',
#   'loss',
#   'lost',
#   'my',
#   'son',
#   'at',
#   'from',
#   'drug',
#   'overdose',
#   'fentanyl',
#   'life',
#   'will',
#   'never',
#   'be',
#   'the',
#   'same'],
#  ['so', 'sorry', 'for', 'your', 'loss'],
#  ['so',
#   'very',
#   'sorry',
#   'no',
#   'one',
#   'can',
#   'bring',
#   'him',
#   'back',
#   'but',
#   'plz',
#   'know',
#   'we',
#   'are',
#   'hurting',
#   'for',
#   'you',
#   'too'],
#  ['am',
#   'so',
#   'so',
#   'sorry',
#   'for',
#   'the',
#   'loss',
#   'of',
#   'your',
#   'son',
#   'they',
#   'need',
#   'to',
#   'get',
#   'this',
#   'poison',
#   'off',
#   'the',
#   'street',
#   'too',
#   'many',
#   'innocent',
#   'people',
#   'dying'],
#  ['always',
#   'breaks',
#   'my',
#   'heart',
#   'when',
#   'we',
#   'lose',
#   'another',
#   'to',
#   'this',
#   'drug',
#   'rest',
#   'easy',
#   'sir',
#   'your',
#   'battle',
#   'is',
#   'over'],
#  ['so', 'sorry'],
#  ['mine', 'too'],
#  ['horrific', 'sending', 'you', 'prayers', 'you', 'find', 'peace'],
#  ['so', 'sorry'],
#  ['so',
#   'sorry',
#   'this',
#   'is',
#   'just',
#   'tragic',
#   'loosing',
#   'so',
#   'many',
#   'of',
#   'our',
#   'young',
#   'people'],
#  ['so', 'sorry', 'for', 'your', 'loss'],
#  ['rip',
#   'bro',
#   'hope',
#   'that',
#   'mf',
#   'lives',
#   'in',
#   'his',
#   'hate',
#   'forever',
#   'who',
#   'did',
#   'this',
#   'people',
#   'are',
#   'ruthless',
#   'anymore',
#   'you',
#   'find',
#   'real',
#   'ones',
#   'rock',
#   'always'],
#  ['that',
#   'happened',
#   'to',
#   'my',
#   'cousin',
#   'too',
#   'his',
#   'son',
#   'was',
#   'yrs',
#   'so',
#   'sad',
#   'some',
#   'families',
#   'grief',
#   'change',
#   'toward',
#   'ea',
#   'other',
#   'peace',
#   'always'],
#  ['so', 'sorry', 'for', 'your', 'loss'],
#  ['im',
#   'so',
#   'sorry',
#   'for',
#   'your',
#   'loss',
#   'lost',
#   'my',
#   'kristopher',
#   'yo',
#   'it',
#   'was',
#   'xanax',
#   'laced',
#   'in',
#   'fentanyl'],
#  ['so',
#   'sorry',
#   'for',
#   'your',
#   'loss',
#   'rest',
#   'in',
#   'paradise',
#   'young',
#   'man'],
#  ['im',
#   'so',
#   'sorry',
#   'for',
#   'your',
#   'loss',
#   'fuck',
#   'fentalyl',
#   'dealer',
#   'recover',
#   'addicted',
#   'from',
#   'fucking',
#   'fentalyl'],
#  ['wow', 'hope', 'they', 'cause', 'the', 'people', 'responsible'],
#  ['ain', 'no', 'way', 'wtf', 'no', 'more', 'laws', 'lawless'],
#  ['for',
#   'real',
#   'for',
#   'real',
#   'this',
#   'is',
#   'so',
#   'sad',
#   'where',
#   'in',
#   'the',
#   'justice'],
#  ['all',
#   'original',
#   'browns',
#   'need',
#   'to',
#   'separate',
#   'from',
#   'all',
#   'these',
#   'evil',
#   'ingrates',
#   'we',
#   'were',
#   'created',
#   'special',
#   'to',
#   'stand',
#   'out',
#   'not',
#   'mix',
#   'with'],
#  ['time', 'to', 'hunt', 'them', 'down'],
#  ['nothing',
#   'going',
#   'to',
#   'be',
#   'done',
#   'we',
#   'dont',
#   'stick',
#   'together',
#   'at',
#   'all'],
#  ['so', 'fucked', 'up'],
#  ['if',
#   'her',
#   'family',
#   'doesnt',
#   'get',
#   'any',
#   'justice',
#   'street',
#   'justice',
#   'is',
#   'always',
#   'an',
#   'option',
#   'remember'],
#  ['post',
#   'the',
#   'officers',
#   'pics',
#   'for',
#   'black',
#   'twitter',
#   'to',
#   'air',
#   'them',
#   'out',
#   'asap'],
#  ['they',
#   'showing',
#   'up',
#   'for',
#   'her',
#   'and',
#   'trying',
#   'to',
#   'get',
#   'this',
#   'case',
#   'some',
#   'attention',
#   'theyre',
#   'on',
#   'it',
#   'from',
#   'what',
#   'see'],
#  ['only', 'in', 'am', 'america', 'pitiful'],
#  ['that', 'not', 'justice'],
#  ['hell', 'naw', 'this', 'ain', 'true', 'couldn', 'be'],
#  ['not',
#   'fake',
#   'at',
#   'all',
#   'wouldnt',
#   'even',
#   'post',
#   'it',
#   'if',
#   'it',
#   'was'],
#  ['thats',
#   'true',
#   'but',
#   'even',
#   'still',
#   'matter',
#   'more',
#   'so',
#   'imagine',
#   'that'],
#  ['google', 'youll', 'see', 'im', 'st', 'sad', 'for', 'you', 'and', 'family'],
#  ['wtf', 'unreal', 'sad', 'just', 'fucking', 'sad'],
#  ['this', 'is', 'horrible'],
#  ['gods', 'justice', 'will', 'be', 'served', 'in', 'time', 'believe'],
#  ['this',
#   'story',
#   'doesnt',
#   'even',
#   'add',
#   'up',
#   'aint',
#   'supposed',
#   'to',
#   'report',
#   'that'],
#  ['so', 'very', 'sad'],
#  ['love',
#   'it',
#   'gurl',
#   'lil',
#   'gurl',
#   'boy',
#   'boy',
#   'go',
#   'tell',
#   'somebody',
#   'who',
#   'care',
#   'giving',
#   'out',
#   'sympathy',
#   'parties',
#   'laugh',
#   'at',
#   'yall',
#   'problems',
#   'funerals',
#   'facts',
#   'its',
#   'the',
#   'dark',
#   'female'],
#  ['rip', 'beautiful'],
#  ['woww',
#   'wtf',
#   'how',
#   'is',
#   'the',
#   'charges',
#   'dropped',
#   'when',
#   'they',
#   'supposedly',
#   'found',
#   'her',
#   'dead',
#   'body',
#   'then',
#   'burned',
#   'it',
#   'woww',
#   'black',
#   'people',
#   'better',
#   'wake',
#   'tf',
#   'up'],
#  ['bill',
#   'shit',
#   'don',
#   'let',
#   'that',
#   'go',
#   'family',
#   'should',
#   'get',
#   'lawyer'],
#  ['where', 'is', 'the', 'out', 'rage', 'for', 'this', 'poor', 'girl'],
#  ['rest', 'in', 'piss', 'sistas', 'lmgdao'],
#  ['wtf', 'is', 'this', 'serious', 'why'],
#  ['happens',
#   'everyday',
#   'but',
#   'one',
#   'day',
#   'this',
#   'will',
#   'end',
#   'no',
#   'justice',
#   'no',
#   'peace',
#   'rest',
#   'well',
#   'my',
#   'god',
#   'be',
#   'with',
#   'family',
#   'try',
#   'to',
#   'hold',
#   'on',
#   'know',
#   'its',
#   'hard'],
#  ['throw',
#   'her',
#   'away',
#   'like',
#   'piece',
#   'of',
#   'trash',
#   'and',
#   'get',
#   'to',
#   'walk',
#   'away',
#   'feds',
#   'need',
#   'to',
#   'step',
#   'inn',
#   'asap'],
#  ['omg',
#   'sure',
#   'they',
#   'are',
#   'in',
#   'prison',
#   'cops',
#   'these',
#   'days',
#   'go',
#   'to',
#   'prison',
#   'for',
#   'handcuffing',
#   'black',
#   'man',
#   'and',
#   'trying',
#   'to',
#   'take',
#   'him',
#   'to',
#   'jail',
#   'for',
#   'committing',
#   'crimes'],
#  ['hmmm',
#   'sounds',
#   'like',
#   'they',
#   'burned',
#   'it',
#   'to',
#   'destroy',
#   'evidence',
#   'the',
#   'question',
#   'is',
#   'what',
#   'evidence'],
#  ...]

# %%
data = pd.read_csv("../combined_comments_3.csv", encoding='utf-8')
data = data.dropna(subset=['text'])
data = data.rename(columns={'text': 'message', 'id':'message_id'})
data = data.reset_index()

threshold = 3
data['message_split'] = [i.split(' ') for i in data['message']]
lengths = [len(i) for i in data['message_split']]

drop_ids = [i for i in range(len(lengths)) if lengths[i] < threshold]
data = data.drop(drop_ids)
data = data.drop(['message_split', 'index'], axis=1)
data = data.reset_index().drop(['index'], axis=1)
data
# Out:
#         create_time    message_id  like_count  parent_comment_id  reply_count  \
# 0      1.698725e+09  7.295967e+18         0.0       7.260153e+18          0.0
# 1      1.698725e+09  7.295968e+18         0.0       7.260153e+18          0.0
# 2      1.698725e+09  7.295967e+18         0.0       7.260153e+18          0.0
# 3      1.699370e+09  7.298738e+18         0.0       7.298692e+18          0.0
# 4      1.673488e+09  7.187574e+18         0.0       7.187541e+18          0.0
# ...             ...           ...         ...                ...          ...
# 69062  1.690226e+09  7.259465e+18         1.0       7.255254e+18          0.0
# 69063  1.690226e+09  7.259465e+18         1.0       7.255254e+18          0.0
# 69064  1.690227e+09  7.259469e+18         1.0       7.255254e+18          0.0
# 69065  1.690226e+09  7.259465e+18         1.0       7.255254e+18          0.0
# 69066  1.690225e+09  7.259460e+18         1.0       7.255254e+18          0.0
#
#                                                  message      video_id
# 0      many of them have no idea they are using fenta...  7.260153e+18
# 1                  your children are spiritual warefare!  7.260153e+18
# 2          i pray they never havevto understand our pain  7.260153e+18
# 3                                           how ya doing  7.298692e+18
# 4                                      Thank you so much  7.187435e+18
# ...                                                  ...           ...
# 69062  of course massive corporations are exploiting ...  7.255007e+18
# 69063  there is no justification for it. someone who ...  7.255007e+18
# 69064  I’m honestly not one to hate on anyone. I can ...  7.255007e+18
# 69065  in what world do you actually think it’s cool ...  7.255007e+18
# 69066  i guess internet likes and views are more impo...  7.255007e+18
#
# [69067 rows x 7 columns]

# %% [markdown]
# # Dendograms

# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
from openai import AzureOpenAI
import os, pickle
import numpy as np

# %%
def generate_embeddings(text, size="SMALL"): # model = "deployment_name"
    client = AzureOpenAI(
      api_key = os.getenv("AZURE_OPENAI_KEY"),  
      api_version = "2024-02-01",
      azure_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")
    )
    
    return client.embeddings.create(input = [text], model=os.getenv(f"DEPLOYMENT_NAME_{size}")).data[0].embedding

# %%
def download_emb(text, embedding_folder=f"{os.getenv('OAK')}/samori/tiktok/embeddings"):
    small_emb = generate_embeddings(text, size="SMALL")
    large_emb = generate_embeddings(text, size="LARGE")
    
    with open(f"{embedding_folder}/gensim_vocab_embedding_small.pkl", "rb") as f:
        emb_dict_small = pickle.load(f)
        emb_dict_small[text] = small_emb

    with open(f"{embedding_folder}/gensim_vocab_embedding_large.pkl", "rb") as f:
        emb_dict_large = pickle.load(f)
        emb_dict_large[text] = large_emb

    with open(f"{embedding_folder}/gensim_vocab_embedding_small.pkl","wb") as f:
        pickle.dump(emb_dict_small, f)

    with open(f"{embedding_folder}/gensim_vocab_embedding_large.pkl","wb") as f:
        pickle.dump(emb_dict_large, f)

    return (emb_dict_small, emb_dict_large)

# %%
def get_filtered_topics(model, threshold=0.80):
    
    # optimal_model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=65, id2word=id2word, random_seed=43)
    topics = model.show_topics(num_topics=66, num_words=16861, formatted=False)
    filtered_topics = {}
    for i in range(len(topics)):
        topic_list = topics[i][1]
        word_dict = {i[0]: i[1] for i in topic_list}
        
        words = list(word_dict.keys())
        values = list(word_dict.values())
    
        cumsum = np.cumsum(values)
        n = np.argmin(cumsum <= threshold)
    
        
        filtered_dict = dict(zip(words[:n], values[:n]))
        filtered_topics[i] = filtered_dict
        
    return filtered_topics

# %%
def get_topic_emb_dict(filtered_topics):

    oak = os.getenv('OAK')
    embedding_folder = f"{oak}/samori/tiktok/embeddings"
    
    with open(f"{embedding_folder}/gensim_vocab_embedding_small.pkl", "rb") as f:
        emb_dict_small = pickle.load(f)
    
    with open(f"{embedding_folder}/gensim_vocab_embedding_large.pkl", "rb") as f:
        emb_dict_large = pickle.load(f)
    
    topic_emb_small_dict = {}
    topic_emb_large_dict = {}
    for i in range(len(list(filtered_topics.keys()))):
        topic_dict_i = filtered_topics[i]
    
        terms = list(topic_dict_i.keys())
        terms = [i.replace("_"," ") for i in terms]
        # print(terms)
        # break
        values = list(topic_dict_i.values())
        values = np.array(values) / np.sum(values)
    
        topic_emb_small = np.zeros(1536)
        topic_emb_large = np.zeros(3072)
        
        for term_id in range(len(terms)):
            try:
                topic_emb_small += values[term_id] * np.array(emb_dict_small[terms[term_id]])
                topic_emb_large += values[term_id] * np.array(emb_dict_large[terms[term_id]])
            except KeyError:
                print(terms[term_id])
                emb_dict_small, emb_dict_large = download_emb(terms[term_id])
                topic_emb_small += values[term_id] * np.array(emb_dict_small[terms[term_id]])
                topic_emb_large += values[term_id] * np.array(emb_dict_large[terms[term_id]])
    
        topic_emb_small_dict[f"{i+1}"] = topic_emb_small
        topic_emb_large_dict[f"{i+1}"] = topic_emb_large
    return topic_emb_small_dict, topic_emb_large_dict

# %%
import gensim
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist
import pandas as pd

# %%
home = os.getenv("HOME")
os.environ.update({'MALLET_HOME':r'/home/users/iasamori/tiktok/mallet-2.0.8/'})
mallet_path = f"{home}/tiktok/mallet-2.0.8/bin/mallet"

data_name = "combined_comments_3"

with open(f"./{data_name}/id2word.pickle", "rb") as f:
    id2word = pickle.load(f)
    
with open(f"./{data_name}/corpus.pickle", "rb") as f:
    corpus = pickle.load(f)

# %%
optimal_model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=65, id2word=id2word, random_seed=43)

# %%
filtered_topics = get_filtered_topics(optimal_model)

# %%
topic_emb_small_dict, topic_emb_large_dict = get_topic_emb_dict(filtered_topics)

# %%
df = pd.DataFrame(np.array(list(topic_emb_small_dict.values())))
dist_matrix = pdist(df)
linkage_matrix = linkage(dist_matrix, method='ward')
